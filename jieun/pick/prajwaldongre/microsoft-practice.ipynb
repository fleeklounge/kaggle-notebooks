# %% [markdown]
# ## 마이크로소프트 주가(2000-2023)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#%conda install plotly

# %%
#%conda install ipykernel

# %%
#conda install nbformat

# %%
df = pd.read_csv('/home/leejieun/workspace/kaggle-notebooks/datasets/prajwaldongre/microsoft-stock-price2000-2023/MSFT(2000-2023).csv')

# %%
df.shape
# Out:
# (6012, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6012 entries, 0 to 6011
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6012 non-null   object
#  1   Open       6012 non-null   float64
#  2   High       6012 non-null   float64
#  3   Low        6012 non-null   float64
#  4   Close      6012 non-null   float64
#  5   Adj Close  6012 non-null   float64
#  6   Volume     6012 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 328.9+ KB

# %%
df.describe().transpose()
# Out:
#             count          mean           std           min           25%  \
# Open       6012.0  7.776766e+01  8.700830e+01  1.520000e+01  2.703000e+01
# High       6012.0  7.858254e+01  8.789798e+01  1.562000e+01  2.730000e+01
# Low        6012.0  7.694153e+01  8.608763e+01  1.487000e+01  2.680750e+01
# Close      6012.0  7.778690e+01  8.703651e+01  1.515000e+01  2.705000e+01
# Adj Close  6012.0  7.078905e+01  8.843845e+01  1.130462e+01  1.902798e+01
# Volume     6012.0  5.132949e+07  3.074841e+07  7.425600e+06  2.865732e+07
#
#                     50%           75%           max
# Open       3.255000e+01  8.422250e+01  3.780000e+02
# High       3.299750e+01  8.472750e+01  3.797900e+02
# Low        3.218750e+01  8.349750e+01  3.749700e+02
# Close      3.263500e+01  8.419250e+01  3.778500e+02
# Adj Close  2.363358e+01  7.847442e+01  3.778500e+02
# Volume     4.605860e+07  6.504930e+07  5.910522e+08

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# ## 산점도
# - 점 위에 커서를 올리면 해당 점의 정확한 좌표값 출력

# %%
from plotly.express import scatter
scatter(data_frame=df, x='Adj Close', y='Volume', height=1000
        , color=df['Date'].dt.year, log_y=True, opacity=0.8) # log_y = 데이터가 치우친 경우 10 단위로 세분화하여 명확한 시각화
# Out:
# <div>                            <div id="5ee85fe4-6f39-4e5a-a0e4-cd158fefa021" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ee85fe4-6f39-4e5a-a0e4-cd158fefa021")) {                    Plotly.newPlot(                        "5ee85fe4-6f39-4e5a-a0e4-cd158fefa021",                        [{"hovertemplate":"Adj Close=%{x}\u003cbr\u003eVolume=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2
# ...
