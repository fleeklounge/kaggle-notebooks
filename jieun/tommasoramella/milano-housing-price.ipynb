# %% [markdown]
# ## 밀라노 주택 가격
# Milano House 발표 - 웹 스크래핑을 통한 데이터셋 생성

# %%
import pandas as pd
import numpy as np
import re
import math

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
def extract_numeric_value(value):
    pattern = r'\d+'
    match = re.search(pattern, value)
    if match:
        return int(match.group())
    else:
        return None

# %%
def convert_to_numeric(df, column):
    return pd.to_numeric(df[column].astype(str).apply(extract_numeric_value), errors='coerce')

# %%
def plot_histogram_violin(df, column, x_label):
    fig, axs = plt.subplots(1,2, figsize=(10,5))
    sns.histplot(
        data = df,
        x = column,
        bins = np.append(np.arange(0, math.ceil(df[column].quantile(0.999)) + 2 , 1), np.inf),
        ax = axs[0]
    )
    axs[0].set_xlabel(x_label)
    axs[0].set_ylabel("Frequency")
    axs[0].set_title(f"{x_label} Histogram")
    
    sns.violinplot(
        data = df,
        y = column,
        ax = axs[1]
    )
    axs[1].set_ylabel(column)
    axs[1].set_xlabel("")
    axs[1].set_title(f"{x_label} Violin Plot")
    
    plt.tight_layout()
    
    plt.show()

# %%
#conda install openpyxl

# %%
df_milan_house_price = pd.read_excel(
    "/home/leejieun/workspace/kaggle-notebooks/datasets/tommasoramella/milano-housing-price/milano_housing_02_2_23.xlsx",
    sheet_name="Sheet1"
)
print(f'Data conntain {df_milan_house_price.shape[0]} records and {df_milan_house_price.shape[1]} columns. \n')

df_milan_house_price.head()
# Out:
# Data conntain 2130 records and 34 columns.
#    index rooms     m2 bathrooms floor condominium_expenses        date  \
# 0      0     3  140.0         2     4                  535  08/02/2023
# 1      0     4  121.0         2     3                  200  17/02/2023
# 2      0     2   55.0         1     4                  133  20/02/2023
# 3      0     2   60.0         1     5                  333  11/01/2023
# 4      0     4  220.0         3     4                  NaN  23/01/2023
#
#   contract                                           typology total_floors  \
# 0     sale  apartment | entire property | stately property...     6 floors
# 1     sale  apartment | entire property | stately property...     7 floors
# 2     sale   attic | entire property | stately property class     4 floors
# 3     sale     attic | bare ownership | medium property class     5 floors
# 4     sale  apartment | entire property | stately property...     7 floors
#
#    ... energy_certification co2_emissions  elevator  floor_level  \
# 0  ...                  NaN           NaN         1            4
# 1  ...                  NaN           NaN         1            3
# 2  ...                  NaN           NaN         1            4
# 3  ...                  NaN           NaN         1            5
# 4  ...                  NaN           NaN         1            4
#
#   heating_centralized heating_radiator      heating_gas  \
# 0         centralized     to radiators  methane powered
# 1          autonomous     to radiators      gas powered
# 2          autonomous     to radiators      gas powered
# 3         centralized     to radiators  methane powered
# 4         centralized     to radiators  methane powered
#
#   air_conditiong_centralized air_conditioning_heat  \
# 0                 autonomous              cold/hot
# 1         system preparation                   NaN
# 2                 autonomous              cold/hot
# 3                 autonomous                  cold
# 4                 autonomous              cold/hot
#
#   renewable_energy_performance_index_KWh/m2
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                     351.0
#
# [5 rows x 34 columns]

# %%
print("Columns with Missing Values: \n")
df_milan_house_price.isnull().sum()
# Out:
# Columns with Missing Values:
# index                                           0
# rooms                                          14
# m2                                             17
# bathrooms                                      25
# floor                                         281
# condominium_expenses                          460
# date                                           14
# contract                                       14
# typology                                       14
# total_floors                                   47
# availability                                  441
# other_features                                 36
# price                                         143
# year_of_build                                 237
# condition                                     113
# air_conditioning                              519
# energy_efficiency                             154
# city                                           14
# neighborhood                                   14
# car_parking                                  1542
# energy_performance_building                  1897
# housing units                                2048
# start_end_works                              2045
# current_building_use                         2121
# energy_certification                         1969
# co2_emissions                                2129
# elevator                                        0
# floor_level                                   101
# heating_centralized                            55
# heating_radiator                              176
# heating_gas                                   378
# air_conditiong_centralized                    519
# air_conditioning_heat                         776
# renewable_energy_performance_index_KWh/m2    2013
# dtype: int64

# %%
Is_selected_columns = [
    "rooms", "m2", "bathrooms", "floor", "condominium_expenses",
    "date", "availability", "price", "year_of_build",
    "condition", "air_conditioning", "energy_efficiency", 
    "neighborhood", "car_parking", "elevator"
]

df_milan_house_price = df_milan_house_price[Is_selected_columns]
 
print(f'Data contain {df_milan_house_price.shape[0]} records and {df_milan_house_price.shape[1]} columns. \n')
 
print("Columns with Missing Values: \n")
df_milan_house_price.isnull().sum()
# Out:
# Data contain 2130 records and 15 columns.
#
# Columns with Missing Values:
# rooms                     14
# m2                        17
# bathrooms                 25
# floor                    281
# condominium_expenses     460
# date                      14
# availability             441
# price                    143
# year_of_build            237
# condition                113
# air_conditioning         519
# energy_efficiency        154
# neighborhood              14
# car_parking             1542
# elevator                   0
# dtype: int64

# %%
df_milan_house_price.dtypes
# Out:
# rooms                    object
# m2                      float64
# bathrooms                object
# floor                    object
# condominium_expenses     object
# date                     object
# availability             object
# price                   float64
# year_of_build           float64
# condition                object
# air_conditioning         object
# energy_efficiency        object
# neighborhood             object
# car_parking              object
# elevator                  int64
# dtype: object

# %%
df_milan_house_price.head(10)
# Out:
#    rooms     m2 bathrooms floor condominium_expenses        date availability  \
# 0      3  140.0         2     4                  535  08/02/2023       libero
# 1      4  121.0         2     3                  200  17/02/2023       libero
# 2      2   55.0         1     4                  133  20/02/2023       libero
# 3      2   60.0         1     5                  333  11/01/2023       libero
# 4      4  220.0         3     4                  NaN  23/01/2023       libero
# 5      4  136.0         2     7                  325  16/02/2023       libero
# 6      4  150.0         2     T                  300  12/01/2023       libero
# 7      2   73.0         1     T                   83  23/02/2023       libero
# 8  3 - 5  216.0         2   NaN                  NaN  21/02/2023          NaN
# 9      4  120.0         3     R                  208  11/01/2023       libero
#
#        price  year_of_build                condition        air_conditioning  \
# 0   880000.0         1900.0  very good / refurbished   autonomous, cold/heat
# 1   649000.0         1960.0  very good / refurbished      system preparation
# 2   300000.0         2006.0         good / habitable   autonomous, cold/heat
# 3   250000.0         1960.0  very good / refurbished        autonomous, cold
# 4  2250000.0         1970.0         good / habitable   autonomous, cold/heat
# 5   920000.0         1969.0         good / habitable   autonomous, cold/heat
# 6   950000.0         1960.0  very good / refurbished   autonomous, cold/heat
# 7   445000.0         1930.0         good / habitable                     NaN
# 8        NaN            NaN                      NaN  centralized, cold/heat
# 9   670000.0         1940.0  very good / refurbished        autonomous, cold
#
#      energy_efficiency               neighborhood      car_parking  elevator
# 0  d248.59 kwh/m² year                   centrale              NaN         1
# 1  e≥ 3,51 kwh/m² year                   centrale              NaN         1
# 2  e183.89 kwh/m² year  viale ungheria - mecenate  1 in garage/box         1
# 3   f138.8 kwh/m² year                città studi              NaN         1
# 4  g≥ 3,51 kwh/m² year          piave - tricolore  1 in garage/box         1
# 5  d167.86 kwh/m² year                     solari  1 in garage/box         1
# 6   f272.1 kwh/m² year                       frua              NaN         1
# 7  g191.52 kwh/m² year                     cadore              NaN         1
# 8   a≥ 175 kwh/m² year             vincenzo monti              NaN         0
# 9  e196.05 kwh/m² year                città studi              NaN         1

# %%
floor_mapping = {
    'S': -1,  # Basement
    'T': 0,   # Ground floor
    'M': 0.5  # Mezzanine
}

ordinal_categories = ['new / under construction', 'very good / refurbished', 'good / habitable', 'to be restructured']
category_codes = ['NEW', 'VG', 'G', 'TBR']
ordinal_dtype = pd.CategoricalDtype(categories = ordinal_categories, ordered = True)

# %% [markdown]
# Categorical

# %%
df_milan_house_price['energy_class'] = df_milan_house_price['energy_efficiency'].str[0].astype('category').str.upper()

# %% [markdown]
# Numeric

# %%
df_milan_house_price['rooms']                = convert_to_numeric(df_milan_house_price, "rooms")
df_milan_house_price['m2']                   = convert_to_numeric(df_milan_house_price, "m2")
df_milan_house_price['bathrooms']            = convert_to_numeric(df_milan_house_price, "bathrooms")
df_milan_house_price['condominium_expenses'] = convert_to_numeric(df_milan_house_price, "condominium_expenses")
df_milan_house_price['floor'] = pd.to_numeric(
    df_milan_house_price['floor'].map(floor_mapping).fillna(df_milan_house_price['floor']),
    errors = 'coerce')

df_milan_house_price['energy_efficiency'] = df_milan_house_price['energy_efficiency'].str.extract(r'(\d+[\.,]?\d*)')
df_milan_house_price['energy_efficiency'] = df_milan_house_price['energy_efficiency'].str.replace(',', '.').astype(float)

# %% [markdown]
# Ordinal

# %%
df_milan_house_price['condition'] = pd.Categorical(
    df_milan_house_price['condition'],
    categories = ordinal_categories,
    ordered = True).rename_categories(category_codes)

# %% [markdown]
# Boolean

# %%
df_milan_house_price['air_conditioning'] = df_milan_house_price['air_conditioning'].fillna(False).astype(bool)
df_milan_house_price['availability']     = df_milan_house_price['availability'].fillna('').astype(bool)
df_milan_house_price['car_parking']      = df_milan_house_price['car_parking'].fillna(False).astype(bool)
df_milan_house_price['elevator']         = df_milan_house_price['elevator'].fillna(False).astype(bool)

# %%
df_milan_house_price.dtypes
# Out:
# rooms                    float64
# m2                       float64
# bathrooms                float64
# floor                    float64
# condominium_expenses     float64
# date                      object
# availability                bool
# price                    float64
# year_of_build            float64
# condition               category
# air_conditioning            bool
# energy_efficiency        float64
# neighborhood              object
# car_parking                 bool
# elevator                    bool
# energy_class              object
# dtype: object

# %%
df_milan_house_price.describe()
# Out:
#              rooms            m2    bathrooms        floor  \
# count  2116.000000  2.113000e+03  2102.000000  1656.000000
# mean      3.525520  7.096091e+02     1.972407     2.923913
# std      16.257119  2.719078e+04     2.855258     2.497178
# min       0.000000  1.000000e+00     1.000000    -1.000000
# 25%       2.000000  7.000000e+01     1.000000     1.000000
# 50%       3.000000  1.000000e+02     2.000000     2.000000
# 75%       4.000000  1.400000e+02     2.000000     4.000000
# max     740.000000  1.250000e+06    71.000000    19.000000
#
#        condominium_expenses         price  year_of_build  energy_efficiency
# count           1670.000000  1.987000e+03    1893.000000        1933.000000
# mean             234.590419  7.311284e+05    1961.295827         147.375629
# std              162.023635  6.619799e+05      52.262219          89.449700
# min                1.000000  2.000000e+04    1100.000000           1.000000
# 25%              125.000000  3.295000e+05    1940.000000         112.000000
# 50%              200.000000  5.200000e+05    1960.000000         175.000000
# 75%              300.000000  8.680000e+05    1990.000000         175.000000
# max              950.000000  5.300000e+06    2025.000000        1167.100000

# %%
#-- Calculate z-scores for each column in the DataFrame
df_milan_house_price_int = df_milan_house_price.select_dtypes(include = ['int', 'float'])
z_scores = np.abs((df_milan_house_price_int - df_milan_house_price_int.mean()) / df_milan_house_price_int.std())

#-- Set a threshold for identifying outliers
threshold = 3

#-- Detect Outliers
outlier_mask = z_scores > threshold

#-- Select rows with outliers
df_mhp_no_outliers = df_milan_house_price[~outlier_mask.any(axis = 1)]
df_mhp_no_outliers
# Out:
#       rooms     m2  bathrooms  floor  condominium_expenses        date  \
# 0       3.0  140.0        2.0    4.0                 535.0  08/02/2023
# 1       4.0  121.0        2.0    3.0                 200.0  17/02/2023
# 2       2.0   55.0        1.0    4.0                 133.0  20/02/2023
# 3       2.0   60.0        1.0    5.0                 333.0  11/01/2023
# 4       4.0  220.0        3.0    4.0                   NaN  23/01/2023
# ...     ...    ...        ...    ...                   ...         ...
# 2125    2.0   70.0        1.0   10.0                 135.0  26/02/2023
# 2126    3.0   90.0        2.0    NaN                 183.0  19/02/2023
# 2127    3.0  130.0        2.0    0.0                 200.0  26/02/2023
# 2128    2.0   51.0        1.0    1.0                   NaN  26/02/2023
# 2129    2.0   72.0        1.0    NaN                 250.0  26/02/2023
#
#       availability      price  year_of_build condition  air_conditioning  \
# 0             True   880000.0         1900.0        VG              True
# 1             True   649000.0         1960.0        VG              True
# 2             True   300000.0         2006.0         G              True
# 3             True   250000.0         1960.0        VG              True
# 4             True  2250000.0         1970.0         G              True
# ...            ...        ...            ...       ...               ...
# 2125          True   338000.0         2009.0        VG              True
# 2126          True   280000.0         1960.0        VG              True
# 2127          True   625000.0         1940.0        VG              True
# 2128          True   440000.0            NaN        VG              True
# 2129          True   355000.0         1969.0       TBR              True
#
#       energy_efficiency               neighborhood  car_parking  elevator  \
# 0                248.59                   centrale        False      True
# 1                  3.51                   centrale        False      True
# 2                183.89  viale ungheria - mecenate         True      True
# 3                138.80                città studi        False      True
# 4                  3.51          piave - tricolore         True      True
# ...                 ...                        ...          ...       ...
# 2125               3.51                    bicocca        False      True
# 2126             174.00                lorenteggio        False      True
# 2127             175.00           melchiorre gioia        False     False
# 2128             193.44              porta venezia        False      True
# 2129             284.99          navigli - darsena         True      True
#
#      energy_class
# 0               D
# 1               E
# 2               E
# 3               F
# 4               G
# ...           ...
# 2125            B
# 2126            F
# 2127            F
# 2128            F
# 2129            F
#
# [1980 rows x 16 columns]

# %%
def draw_cate_vs_target(df, feature):
    plt.grid(True)
    ax = sns.boxenplot(data = df, x = feature, y = 'price')
    
    ax.set_title(f'{feature.capitalize()} Vs. Price', fontdict = {'fontsize': 16})
    ax.set_xlabel(f'# {feature.capitalize()}')
    ax.set_ylabel("Price (in Millions [€])")
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/(1000000)) + 'M €'))
    
def draw_cate_countplot(df, feature):
    plt.grid(True)
    ax = sns.countplot(x = df[feature])
    ax.set_title(f'{feature.capitalize()}\'s count'.capitalize(), fontdict = {'fontsize': 16})
    ax.set_xlabel(f'# {feature.capitalize()}')
    ax.set_ylabel("# Frequency")
    
def draw_subplots(df, feature):
    
    plt.figure(figsize = (20, 6))
    sns.set_palette('Paired')
    
    plt.subplot(1, 2, 1)
    draw_cate_vs_target(df, feature)
    
    plt.subplot(1, 2, 2)
    draw_cate_countplot(df, feature)
    plt.show()

# %%
draw_subplots(df_mhp_no_outliers, "rooms")

# %%
draw_subplots(df_mhp_no_outliers, "bathrooms")

# %%
draw_subplots(df_mhp_no_outliers, "condition")

# %%
draw_subplots(df_mhp_no_outliers, "floor")

# %%
draw_subplots(df_mhp_no_outliers, "elevator")

# %%
sns.pairplot(df_mhp_no_outliers[['m2', 'condominium_expenses', 'price', 'energy_efficiency']], diag_kind= 'hist')
