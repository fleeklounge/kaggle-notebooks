# %% [markdown]
# ## 📊다양한 Nifty 지수 TSA 데이터 (14-02-2023-24)📈
# 인도 주식 시장 부문의 성과와 동향 분석 📊📈

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/leejieun/workspace/kaggle-notebooks/datasets/mohamedfahim003/various-nifty-indices-tsa-data-14-02-2023-24/Nifty50.csv")

# %%
df.head()
# Out:
#          date      open      high       low     close  shares traded  turnover
# 0  2023-02-14  17840.35  17954.55  17800.05  17929.85      244512944  20579.80
# 1  2023-02-15  17896.60  18034.10  17853.80  18015.85      229273800  21457.34
# 2  2023-02-16  18094.75  18134.75  18000.65  18035.85      230246175  18891.55
# 3  2023-02-17  17974.85  18034.25  17884.60  17944.20      208053929  16998.33
# 4  2023-02-20  17965.55  18004.35  17818.40  17844.60      174563233  14729.07

# %%
import seaborn as sns

# %%
df.shape
# Out:
# (247, 7)

# %%
df.isna().sum() / df.shape[0]
# Out:
# date             0.0
# open             0.0
# high             0.0
# low              0.0
# close            0.0
# shares traded    0.0
# turnover         0.0
# dtype: float64

# %%
df.shape[0]
# Out:
# 247

# %%
df.describe()
# Out:
#                open          high           low         close  shares traded  \
# count    247.000000    247.000000    247.000000    247.000000   2.470000e+02
# mean   19381.432591  19446.739271  19291.382186  19371.706883   2.716450e+08
# std     1358.487484   1366.748795   1350.857125   1360.111008   7.908123e+07
# min    16977.300000  17061.750000  16828.350000  16945.050000   3.731190e+07
# 25%    18308.500000  18366.950000  18246.300000  18314.600000   2.248169e+08
# 50%    19449.600000  19494.400000  19366.600000  19428.300000   2.549560e+08
# 75%    19843.925000  19902.125000  19781.200000  19861.425000   2.962497e+08
# max    22080.500000  22126.800000  21969.800000  22097.450000   6.964958e+08
#
#            turnover
# count    247.000000
# mean   24700.671053
# std     7492.974771
# min     2482.270000
# 25%    20187.950000
# 50%    23171.880000
# 75%    26672.945000
# max    70755.080000

# %%
df.duplicated().any()
# Out:
# False

# %%
type(df.date[0])
# Out:
# str

# %%
df.dtypes
# Out:
# date              object
# open             float64
# high             float64
# low              float64
# close            float64
# shares traded      int64
# turnover         float64
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.date = pd.to_datetime(df.date)
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('date', inplace=True)

# %%
df.index.name = None

# %%
df
# Out:
#                 open      high       low     close  shares traded  turnover
# 2023-02-14  17840.35  17954.55  17800.05  17929.85      244512944  20579.80
# 2023-02-15  17896.60  18034.10  17853.80  18015.85      229273800  21457.34
# 2023-02-16  18094.75  18134.75  18000.65  18035.85      230246175  18891.55
# 2023-02-17  17974.85  18034.25  17884.60  17944.20      208053929  16998.33
# 2023-02-20  17965.55  18004.35  17818.40  17844.60      174563233  14729.07
# ...              ...       ...       ...       ...            ...       ...
# 2024-02-07  22045.05  22053.30  21860.15  21930.50      346263704  30088.76
# 2024-02-08  22009.65  22011.05  21665.30  21717.95      491069786  41082.02
# 2024-02-09  21727.00  21804.45  21629.90  21782.50      349222850  31176.16
# 2024-02-12  21800.80  21831.70  21574.75  21616.05      287436165  23921.14
# 2024-02-13  21664.30  21766.80  21543.35  21743.25      365785766  29896.62
#
# [247 rows x 6 columns]

# %%
df['2023': '2024'].plot(subplots=True, figsize=(8,10))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
df.open.plot(figsize=(10,5))
# Out:
# <Axes: >

# %%
fst_df = df.head(100)
plt.figure(figsize=(10,6))
sns.lineplot(x=fst_df.index, y='open', data=fst_df , label='open')
sns.lineplot(x=fst_df.index, y='close', data=fst_df, label='close')
plt.legend()

# %%
fst_df = df.tail(100)
plt.figure(figsize=(10,6))
sns.lineplot(x=fst_df.index, y='open', data=fst_df, label='open')
sns.lineplot(x=fst_df.index, y='close', data=fst_df, label='close')
plt.legend()

# %%
high1 = df.resample('ME').max()
plt.figure(figsize=(10,6))
plt.xticks(rotation=45)
sns.barplot(data=high1, x=high1.index, y="high")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
high1 = df.resample('ME').max()
plt.figure(figsize=(10,6))
plt.xticks(rotation=45)
# sns.barplot(data=high1, x=high1.index, y="high")

sns.lineplot(x=high1.index, y='open', data=high1, label='open')
sns.lineplot(x=high1.index, y='high', data=high1, label='high')
sns.lineplot(x=high1.index, y='low', data=high1, label='low')
sns.lineplot(x=high1.index, y='close', data=high1, label='close')
plt.legend()

# %%
df.resample('ME').max()
# Out:
#                 open      high       low     close  shares traded  turnover
# 2023-02-28  18094.75  18134.75  18000.65  18035.85      420881259  32959.77
# 2023-03-31  17772.05  17799.95  17671.95  17754.40      408121255  30478.42
# 2023-04-30  17950.40  18089.15  17885.30  18065.00      357401212  35118.57
# 2023-05-31  18619.15  18662.45  18581.25  18633.85      696495765  70755.08
# 2023-06-30  19076.85  19201.70  19024.60  19189.05      398782019  37356.94
# 2023-07-31  19850.90  19991.85  19758.40  19979.15      369653496  40163.14
# 2023-08-31  19784.00  19795.60  19704.60  19733.55      562557215  45699.54
# 2023-09-30  20156.45  20222.45  20129.70  20192.35      512974083  42681.35
# 2023-10-31  19843.20  19849.75  19775.65  19811.50      300356469  28939.64
# 2023-11-30  20108.50  20158.70  20015.85  20133.15      486585349  48877.95
# 2023-12-31  21737.65  21801.45  21678.00  21778.70      508761756  50114.46
# ...
