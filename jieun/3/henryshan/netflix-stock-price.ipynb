# %% [markdown]
# ## 넷플릭스 주가
# 실시간 가격. USD 통화

# %%
import numpy as np
import pandas as pd
import math
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/leejieun/kaggle-notebooks/datasets/henryshan/netflix-stock-price/NFLX.csv')

# %%
df.shape
# Out:
# (5422, 7)

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5422.000000  5422.000000  5422.000000  5422.000000  5422.000000
# mean    131.304057   133.340057   129.201970   131.322955   131.322955
# std     172.967612   175.451082   170.335958   172.929156   172.929156
# min       0.377857     0.410714     0.346429     0.372857     0.372857
# 25%       4.107500     4.183214     4.031786     4.112857     4.112857
# 50%      33.700714    34.275714    33.237858    33.833570    33.833570
# 75%     244.832497   250.257496   237.687497   245.152500   245.152500
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  5.422000e+03
# mean   1.594455e+07
# std    1.874197e+07
# min    2.856000e+05
# 25%    5.960725e+06
# 50%    1.006250e+07
# 75%    1.886930e+07
# max    3.234140e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5422 entries, 0 to 5421
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5422 non-null   object
#  1   Open       5422 non-null   float64
#  2   High       5422 non-null   float64
#  3   Low        5422 non-null   float64
#  4   Close      5422 non-null   float64
#  5   Adj Close  5422 non-null   float64
#  6   Volume     5422 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 296.6+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.subplot(2, 1, 1)
df['Open'].plot(lw=1, color='black')
plt.title('Opening Price', fontsize=14, fontweight='bold')

plt.figure(figsize=(15,6))
plt.subplot(2,1,2)
plt.title('Close Price')
df['Close'].plot(lw=1, color='black')
plt.show()

# %%
import datetime

# %%
df.datetime = pd.to_datetime(df.Date)

# %%
df.head()
# Out:
#                   Date      Open      High       Low     Close  Adj Close  \
# Date
# 2002-05-23  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429
# 2002-05-24  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000
# 2002-05-28  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143
# 2002-05-29  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571
# 2002-05-30  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429
#
#                Volume
# Date
# 2002-05-23  104790000
# 2002-05-24   11104800
# 2002-05-28    6609400
# 2002-05-29    6757800
# 2002-05-30   10154200

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.index = df['Date']

df_month = df.resample('M')['Date'].mean()

# %%
plt.figure(figsize=(15,6))
plt.suptitle("open-close")

plt.subplot(211)
plt.plot(df['Date'],df['Open'])
plt.title('Open')

plt.subplot(212)
plt.plot(df['Date'],df['Close'])
plt.title('Close')
plt.show()

# %%
df.head()
# Out:
#                  Date      Open      High       Low     Close  Adj Close  \
# Date
# 2002-05-23 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429
# 2002-05-24 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000
# 2002-05-28 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143
# 2002-05-29 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571
# 2002-05-30 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429
#
#                Volume
# Date
# 2002-05-23  104790000
# 2002-05-24   11104800
# 2002-05-28    6609400
# 2002-05-29    6757800
# 2002-05-30   10154200

# %%
plt.figure(figsize=(16,6))
plt.plot(df['Volume'], lw=1, color='red') # lw : 선의 두께
plt.xlabel('Date', fontsize=18)
plt.ylabel('Price USD', fontsize=18)
plt.title('Sales Volume of Netflix')
plt.show()
