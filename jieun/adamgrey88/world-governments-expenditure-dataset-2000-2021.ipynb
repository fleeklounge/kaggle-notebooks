# %% [markdown]
# ## 세계 정부 지출 데이터 세트 (2000-2021)
# 정부 지출 패턴을 살펴보세요.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#/world-governments-expenditure-dataset-2000-2021
import os
for dirname, _, filenames in os.walk('/home/leejieun/workspace/kaggle-notebooks/datasets/adamgrey88'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /home/leejieun/workspace/kaggle-notebooks/datasets/adamgrey88/world-governments-expenditure-dataset-2000-2021/WorldExpenditures.csv
# /home/leejieun/workspace/kaggle-notebooks/datasets/adamgrey88/world-governments-expenditure-dataset-2000-2021/economie-mondiale.jpg

# %%
df = pd.read_csv('/home/leejieun/workspace/kaggle-notebooks/datasets/adamgrey88/world-governments-expenditure-dataset-2000-2021/WorldExpenditures.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0  Year    Country                                      Sector  \
# 0           0  2000  Australia                              Total function
# 1           1  2000  Australia  Agriculture, forestry, fishing and hunting
# 2           2  2000  Australia      Mining, manufacturing and construction
#
#    Expenditure(million USD)    GDP(%)
# 0                153122.633  37.36193
# 1                  2195.583   0.53572
# 2                   905.018   0.22082

# %%
def ulkeSec(ulke):
    df=pd.read_csv('/home/leejieun/workspace/kaggle-notebooks/datasets/adamgrey88/world-governments-expenditure-dataset-2000-2021/WorldExpenditures.csv')
    ulkedf=df[df['Country'] ==ulke]
    return ulkedf

# %%
ulkeSec('Türkiye')
# Out:
#        Unnamed: 0  Year  Country  \
# 9000         9000  2008  Türkiye
# 9001         9001  2008  Türkiye
# 9002         9002  2008  Türkiye
# 9003         9003  2008  Türkiye
# 9004         9004  2008  Türkiye
# ...           ...   ...      ...
# 25680       25680  2021  Türkiye
# 25681       25681  2021  Türkiye
# 25682       25682  2021  Türkiye
# 25683       25683  2021  Türkiye
# 25684       25684  2021  Türkiye
#
#                                                 Sector  \
# 9000                                    Total function
# 9001        Agriculture, forestry, fishing and hunting
# 9002            Mining, manufacturing and construction
# 9003                                         Transport
# 9004                                     Communication
# ...                                                ...
# 25680                 Recreation, culture and religion
# 25681  General economic, commercial and labour affairs
# 25682                                 Other industries
# 25683                           RandD Economic affairs
# 25684                          Economic affairs n.e.c.
#
#        Expenditure(million USD)    GDP(%)
# 9000                 262747.059  34.10309
# 9001                   8245.994   1.07028
# 9002                   1498.014   0.19443
# 9003                  13499.754   1.75219
# 9004                    363.265   0.04715
# ...                         ...       ...
# 25680                  4929.245   0.60184
# 25681                  6758.647   0.82520
# 25682                  2703.394   0.33007
# 25683                    81.196   0.00991
# 25684                    94.009   0.01148
#
# [241 rows x 6 columns]

# %%
df['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium',
#        'Bolivia (Plurinational State of)', 'Brazil', 'Bulgaria',
#        'China, Macao SAR', 'Croatia', 'Cyprus', 'Czechia', 'Denmark',
#        'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 'Greece',
#        'Hungary', 'Iceland', 'Indonesia', 'Ireland', 'Israel', 'Italy',
#        'Kazakhstan', 'Korea, Republic of', 'Latvia', 'Lithuania',
#        'Luxembourg', 'Malaysia', 'Maldives', 'Malta', 'Mongolia',
#        'Netherlands (Kingdom of the)', 'Norway', 'Panama', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Romania',
#        'Russian Federation', 'Serbia', 'Seychelles', 'Singapore',
#        'Slovakia', 'Slovenia', 'South Africa', 'Spain', 'Sri Lanka',
#        'Sweden', 'Switzerland, Liechtenstein', 'Thailand', 'Timor-Leste',
#        'United Kingdom', 'United States of America',
#        'Iran (Islamic Republic of)', 'Kuwait', 'Ukraine',
#        'China, Hong Kong SAR', 'Egypt', 'El Salvador', 'Mauritius',
#        'Moldova, Republic of', 'San Marino', 'Yemen', 'Belarus',
#        'Paraguay', 'Armenia', 'Albania', 'China', 'Fiji', 'Japan',
#        'Afghanistan', 'Serbia and Montenegro', 'Azerbaijan', 'Canada',
#        'Türkiye', 'Colombia', 'Cook Islands', 'New Zealand',
#        'Marshall Islands', 'Samoa', 'India', 'Kiribati', 'Vanuatu',
#        'Costa Rica', 'Myanmar', 'Tuvalu', 'Chile', 'Uzbekistan',
#        'Guatemala', 'Kenya', 'Kyrgyzstan', 'Nauru', 'Somalia', 'Nepal'],
#       dtype=object)

# %%
df['Sector'].value_counts()
# Out:
# Sector
# Total function                                     1638
# Health                                             1587
# General public services                            1587
# Education                                          1586
# Housing and community amenities                    1580
# Public order and safety                            1570
# Social protection                                  1561
# Recreation, culture and religion                   1533
# Defence                                            1532
# Environment protection                             1517
# Transport                                          1223
# Agriculture, forestry, fishing and hunting         1223
# Fuel and energy                                    1192
# Mining, manufacturing and construction             1173
# Communication                                      1148
# General economic, commercial and labour affairs    1069
# Other industries                                   1034
# RandD Economic affairs                              977
# Economic affairs n.e.c.                             957
# Others                                               46
# Name: count, dtype: int64

# %%
df_saglik=df[df['Sector'] =='Health']

# %%
df_saglik
# Out:
#        Unnamed: 0  Year                   Country  Sector  \
# 7               7  2000                 Australia  Health
# 26             26  2000                   Austria  Health
# 40             40  2000                   Belgium  Health
# 55             55  2000                    Brazil  Health
# 72             72  2000                  Bulgaria  Health
# ...           ...   ...                       ...     ...
# 25655       25655  2021                  Thailand  Health
# 25674       25674  2021                   Türkiye  Health
# 25693       25693  2021                   Ukraine  Health
# 25712       25712  2021            United Kingdom  Health
# 25726       25726  2021  United States of America  Health
#
#        Expenditure(million USD)    GDP(%)
# 7                     24071.984   5.87357
# 26                    14053.707   7.14112
# 40                    14863.604   6.29269
# 55                    25159.483   3.83852
# 72                      507.282   3.82970
# ...                         ...       ...
# 25655                  9059.829   1.79054
# 25674                 42763.002   5.22115
# 25693                  7504.529   3.75066
# 25712                309913.168   9.89702
# 25726               2399530.230  10.24494
#
# [1587 rows x 6 columns]

# %%
saglikgr= df_saglik.groupby(by="Country").mean(numeric_only=True)

# %%
saglikgr.sort_values("GDP(%)", ascending=False).index
# Out:
# Index(['Kiribati', 'Nauru', 'Tuvalu', 'Marshall Islands', 'Canada',
#        'United States of America', 'Denmark', 'Austria', 'France', 'Norway',
#        'Iceland', 'Czechia', 'Belgium', 'Japan', 'Slovakia', 'United Kingdom',
#        'Germany', 'Finland', 'Australia', 'Netherlands (Kingdom of the)',
#        'Italy', 'Portugal', 'Sweden', 'New Zealand', 'Slovenia', 'Costa Rica',
#        'Ireland', 'Spain', 'Greece', 'San Marino', 'Türkiye', 'Malta',
#        'Colombia', 'Israel', 'Hungary', 'Serbia', 'Estonia',
#        'Serbia and Montenegro', 'Luxembourg', 'Lithuania', 'Samoa', 'Chile',
#        'Bulgaria', 'Poland', 'Brazil', 'Timor-Leste', 'Belarus',
#        'Moldova, Republic of', 'Romania', 'South Africa', 'Latvia',
#        'El Salvador', 'Ukraine', 'Maldives', 'Korea, Republic of',
#        'Kyrgyzstan', 'Seychelles', 'Bolivia (Plurinational State of)',
#        'Cook Islands', 'Russian Federation', 'Cyprus', 'Mongolia', 'Albania',
#        'China, Hong Kong SAR', 'Fiji', 'Vanuatu', 'Kazakhstan', 'Panama',
#        'Paraguay', 'Kuwait', 'Uzbekistan', 'Afghanistan', 'Mauritius',
#        'Guatemala', 'Peru', 'China, Macao SAR', 'Kenya', 'Georgia',
#        'Switzerland, Liechtenstein', 'Nepal', 'Malaysia', 'Armenia', 'China',
#        'Singapore', 'Egypt', 'Sri Lanka', 'Iran (Islamic Republic of)',
#        'Yemen', 'Thailand', 'Indonesia', 'Azerbaijan', 'India', 'Croatia',
#        'Myanmar', 'Philippines', 'Somalia'],
#       dtype='object', name='Country')

# %%
df.head(3)
# Out:
#    Unnamed: 0  Year    Country                                      Sector  \
# 0           0  2000  Australia                              Total function
# 1           1  2000  Australia  Agriculture, forestry, fishing and hunting
# 2           2  2000  Australia      Mining, manufacturing and construction
#
#    Expenditure(million USD)    GDP(%)
# 0                153122.633  37.36193
# 1                  2195.583   0.53572
# 2                   905.018   0.22082

# %%
ulkeSec('Türkiye')
# Out:
#        Unnamed: 0  Year  Country  \
# 9000         9000  2008  Türkiye
# 9001         9001  2008  Türkiye
# 9002         9002  2008  Türkiye
# 9003         9003  2008  Türkiye
# 9004         9004  2008  Türkiye
# ...           ...   ...      ...
# 25680       25680  2021  Türkiye
# 25681       25681  2021  Türkiye
# 25682       25682  2021  Türkiye
# 25683       25683  2021  Türkiye
# 25684       25684  2021  Türkiye
#
#                                                 Sector  \
# 9000                                    Total function
# 9001        Agriculture, forestry, fishing and hunting
# 9002            Mining, manufacturing and construction
# 9003                                         Transport
# 9004                                     Communication
# ...                                                ...
# 25680                 Recreation, culture and religion
# 25681  General economic, commercial and labour affairs
# 25682                                 Other industries
# 25683                           RandD Economic affairs
# 25684                          Economic affairs n.e.c.
#
#        Expenditure(million USD)    GDP(%)
# 9000                 262747.059  34.10309
# 9001                   8245.994   1.07028
# 9002                   1498.014   0.19443
# 9003                  13499.754   1.75219
# 9004                    363.265   0.04715
# ...                         ...       ...
# 25680                  4929.245   0.60184
# 25681                  6758.647   0.82520
# 25682                  2703.394   0.33007
# 25683                    81.196   0.00991
# 25684                    94.009   0.01148
#
# [241 rows x 6 columns]

# %%
def harcamaPlot(ulke, sektor):
    tr=ulkeSec(ulke)
    egitim = tr[tr['Sector'] ==sektor]
    egitim.head(3)
    plt.style.use("fivethirtyeight")
    plt.figure(figsize=(16,5))
    plt.plot(egitim['Year'].astype('str'), egitim['Expenditure(million USD)'])
    plt.show()

# %%
harcamaPlot("Türkiye", "Education")

# %%
harcamaPlot("Türkiye","Health")

# %%
harcamaPlot('Türkiye','Defence')

# %%
tr=ulkeSec("Türkiye")

# %%
tr2021=tr[tr['Year']==2021]

# %%
tr2021.head()
# Out:
#        Unnamed: 0  Year  Country                                      Sector  \
# 25666       25666  2021  Türkiye                              Total function
# 25667       25667  2021  Türkiye  Agriculture, forestry, fishing and hunting
# 25668       25668  2021  Türkiye      Mining, manufacturing and construction
# 25669       25669  2021  Türkiye                                   Transport
# 25670       25670  2021  Türkiye                               Communication
#
#        Expenditure(million USD)    GDP(%)
# 25666                264520.022  32.29657
# 25667                  6216.620   0.75902
# 25668                  1495.772   0.18263
# 25669                 13798.687   1.68475
# 25670                   113.061   0.01380

# %%
tr2021 = tr2021.iloc[1:]
plt.style.use('fivethirtyeight')
plt.figure(figsize=(16,16))
plt.pie(tr2021['Expenditure(million USD)'],labels=tr2021['Sector'],autopct="%1.1f%%")
plt.show()
