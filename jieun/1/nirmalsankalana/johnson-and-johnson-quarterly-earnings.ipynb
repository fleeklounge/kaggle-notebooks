# %% [markdown]
# ## Johnson & Johnson 주식당 분기별 수익
# Johnson & Johnson 주식당 분기별 수익(달러) 1960-80.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/leejieun/workspace/kaggle-notebooks/datasets/nirmalsankalana/johnson-and-johnson-quarterly-earnings/data.csv")

# %%
df = df.drop(['Unnamed: 0', 'X'], axis=1)

# %%
df.head()
# Out:
#       time  value
# 0  1960.00   0.71
# 1  1960.25   0.63
# 2  1960.50   0.85
# 3  1960.75   0.44
# 4  1961.00   0.61

# %%
sns.lineplot(data=df, x='time', y='value')
# Out:
# <Axes: xlabel='time', ylabel='value'>

# %%
plt.plot(df['time'], df['value'])
plt.show()

# %%
df.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
df.shape
# Out:
# (84, 2)

# %%
df.describe()
# Out:
#               time      value
# count    84.000000  84.000000
# mean   1970.375000   4.799762
# std       6.098155   4.309991
# min    1960.000000   0.440000
# 25%    1965.187500   1.247500
# 50%    1970.375000   3.510000
# 75%    1975.562500   7.132500
# max    1980.750000  16.200000
