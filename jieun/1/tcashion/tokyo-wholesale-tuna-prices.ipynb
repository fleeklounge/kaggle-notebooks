# %% [markdown]
# ## 츠키지 참치 가격 - 시계열 🐟
# 츠키지 수산 시장의 월간 참치 가격

# %%
import datetime
import numpy as np
import pandas as pd

# %%
#conda install prophet
# Out:
# Channels:
#  - conda-forge
#  - nvidia
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/leejieun/miniforge3/envs/ai
#
#   added / updated specs:
#     - prophet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     binutils_impl_linux-64-2.40|       hf600244_0         5.2 MB  conda-forge
#     binutils_linux-64-2.40     |       hdade7a5_3          28 KB  conda-forge
#     cmdstan-2.33.1             |       hff4ab46_0        46.0 MB  conda-forge
#     cmdstanpy-1.2.2            |     pyhd8ed1ab_0          69 KB  conda-forge
#     convertdate-2.4.0          |     pyhd8ed1ab_0          38 KB  conda-forge
#     ephem-4.1.5                |  py312h98912ed_1         1.3 MB  conda-forge
#     gcc_impl_linux-64-12.3.0   |       he2b93b0_5        49.5 MB  conda-forge
#     gcc_linux-64-12.3.0        |       h6477408_3          30 KB  conda-forge
#     gxx_impl_linux-64-12.3.0   |       he2b93b0_5        12.2 MB  conda-forge
#     gxx_linux-64-12.3.0        |       h4a1b8e8_3          29 KB  conda-forge
#     holidays-0.45              |     pyhd8ed1ab_0         341 KB  conda-forge
#     kernel-headers_linux-64-2.6.32|      he073ed8_17         694 KB  conda-forge
#     libgcc-devel_linux-64-12.3.0|     h8bca6fd_105         2.4 MB  conda-forge
#     libsanitizer-12.3.0        |       h0f45ef3_5         3.7 MB  conda-forge
#     libstdcxx-devel_linux-64-12.3.0|     h8bca6fd_105        11.1 MB  conda-forge
#     lunarcalendar-0.0.9        |             py_0          20 KB  conda-forge
#     make-4.3                   |       hd18ef5c_1         507 KB  conda-forge
#     prophet-1.1.5              |  py312h4f541b2_1         847 KB  conda-forge
#     pymeeus-0.5.12             |     pyhd8ed1ab_0         507 KB  conda-forge
#     stanio-0.5.0               |     pyhd8ed1ab_0          13 KB  conda-forge
#     sysroot_linux-64-2.12      |      he073ed8_17        14.4 MB  conda-forge
#     tbb-devel-2021.11.0        |       h5ccd973_1         1.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       149.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   binutils_impl_lin~ conda-forge/linux-64::binutils_impl_linux-64-2.40-hf600244_0
#   binutils_linux-64  conda-forge/linux-64::binutils_linux-64-2.40-hdade7a5_3
#   cmdstan            conda-forge/linux-64::cmdstan-2.33.1-hff4ab46_0
#   cmdstanpy          conda-forge/noarch::cmdstanpy-1.2.2-pyhd8ed1ab_0
#   convertdate        conda-forge/noarch::convertdate-2.4.0-pyhd8ed1ab_0
#   ephem              conda-forge/linux-64::ephem-4.1.5-py312h98912ed_1
#   gcc_impl_linux-64  conda-forge/linux-64::gcc_impl_linux-64-12.3.0-he2b93b0_5
#   gcc_linux-64       conda-forge/linux-64::gcc_linux-64-12.3.0-h6477408_3
#   gxx_impl_linux-64  conda-forge/linux-64::gxx_impl_linux-64-12.3.0-he2b93b0_5
#   gxx_linux-64       conda-forge/linux-64::gxx_linux-64-12.3.0-h4a1b8e8_3
#   holidays           conda-forge/noarch::holidays-0.45-pyhd8ed1ab_0
#   kernel-headers_li~ conda-forge/noarch::kernel-headers_linux-64-2.6.32-he073ed8_17
#   libgcc-devel_linu~ conda-forge/noarch::libgcc-devel_linux-64-12.3.0-h8bca6fd_105
#   libsanitizer       conda-forge/linux-64::libsanitizer-12.3.0-h0f45ef3_5
#   libstdcxx-devel_l~ conda-forge/noarch::libstdcxx-devel_linux-64-12.3.0-h8bca6fd_105
#   lunarcalendar      conda-forge/noarch::lunarcalendar-0.0.9-py_0
#   make               conda-forge/linux-64::make-4.3-hd18ef5c_1
#   prophet            conda-forge/linux-64::prophet-1.1.5-py312h4f541b2_1
#   pymeeus            conda-forge/noarch::pymeeus-0.5.12-pyhd8ed1ab_0
#   stanio             conda-forge/noarch::stanio-0.5.0-pyhd8ed1ab_0
#   sysroot_linux-64   conda-forge/noarch::sysroot_linux-64-2.12-he073ed8_17
#   tbb-devel          conda-forge/linux-64::tbb-devel-2021.11.0-h5ccd973_1
#
#
#
# Downloading and Extracting Packages:
# gcc_impl_linux-64-12 | 49.5 MB   |                                       |   0%
# cmdstan-2.33.1       | 46.0 MB   |                                       |   0%
#
# sysroot_linux-64-2.1 | 14.4 MB   |                                       |   0%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   |                                       |   0%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   |                                       |   0%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    |                                       |   0%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    |                                       |   0%
#
#
#
#
#
#
#
# ephem-4.1.5          | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# tbb-devel-2021.11.0  | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# prophet-1.1.5        | 847 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# kernel-headers_linux | 694 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# pymeeus-0.5.12       | 507 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# make-4.3             | 507 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# holidays-0.45        | 341 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.2.2      | 69 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# convertdate-2.4.0    | 38 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_linux-64-12.3.0  | 30 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_linux-64-12.3.0  | 29 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_linux-64-2. | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lunarcalendar-0.0.9  | 20 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   |                                       |   0%
#
# sysroot_linux-64-2.1 | 14.4 MB   | 3                                     |   1%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | 2                                     |   1%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | 1                                     |   0%
# cmdstan-2.33.1       | 46.0 MB   |                                       |   0%
#
# gcc_impl_linux-64-12 | 49.5 MB   |                                       |   0%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | 8                                     |   2%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | 7                                     |   2%
# cmdstan-2.33.1       | 46.0 MB   |                                       |   0%
#
# gcc_impl_linux-64-12 | 49.5 MB   | 1                                     |   0%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##1                                   |   6%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #6                                    |   5%
# cmdstan-2.33.1       | 46.0 MB   |                                       |   0%
#
# gcc_impl_linux-64-12 | 49.5 MB   | 3                                     |   1%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##9                                   |   8%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##5                                   |   7%
# cmdstan-2.33.1       | 46.0 MB   | 2                                     |   1%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ####8                                 |  13%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | 5                                     |   1%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ###1                                  |   9%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #####9                                |  16%
# gcc_impl_linux-64-12 | 49.5 MB   | 6                                     |   2%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ####5                                 |  12%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ####                                  |  11%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #######                               |  19%
# cmdstan-2.33.1       | 46.0 MB   | 5                                     |   1%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | 7                                     |   2%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ####8                                 |  13%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ########                              |  22%
# gcc_impl_linux-64-12 | 49.5 MB   | 9                                     |   2%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #####5                                |  15%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ######                                |  16%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #########                             |  25%
# gcc_impl_linux-64-12 | 49.5 MB   | #                                     |   3%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ######2                               |  17%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ######8                               |  19%
#
# gcc_impl_linux-64-12 | 49.5 MB   | #1                                    |   3%
# cmdstan-2.33.1       | 46.0 MB   | #                                     |   3%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ######9                               |  19%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #######5                              |  20%
#
# gcc_impl_linux-64-12 | 49.5 MB   | #2                                    |   3%
# cmdstan-2.33.1       | 46.0 MB   | #1                                    |   3%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #######7                              |  21%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ########4                             |  23%
# cmdstan-2.33.1       | 46.0 MB   | #2                                    |   3%
#
# gcc_impl_linux-64-12 | 49.5 MB   | #3                                    |   4%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #########1                            |  25%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ########4                             |  23%
# gcc_impl_linux-64-12 | 49.5 MB   | #4                                    |   4%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #############2                        |  36%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##########                            |  27%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #########5                            |  26%
#
# gcc_impl_linux-64-12 | 49.5 MB   | #6                                    |   4%
# cmdstan-2.33.1       | 46.0 MB   | #5                                    |   4%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##########3                           |  28%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##########7                           |  29%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ###############                       |  41%
# gcc_impl_linux-64-12 | 49.5 MB   | #7                                    |   5%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ###########4                          |  31%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ###########                           |  30%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ###############9                      |  43%
# gcc_impl_linux-64-12 | 49.5 MB   | #8                                    |   5%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ############2                         |  33%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ###########8                          |  32%
# cmdstan-2.33.1       | 46.0 MB   | #8                                    |   5%
#
# gcc_impl_linux-64-12 | 49.5 MB   | #9                                    |   5%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #############                         |  35%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ############5                         |  34%
# cmdstan-2.33.1       | 46.0 MB   | ##                                    |   5%
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##                                    |   6%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #############2                        |  36%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #############6                        |  37%
# cmdstan-2.33.1       | 46.0 MB   | ##1                                   |   6%
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##1                                   |   6%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##############3                       |  39%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##############                        |  38%
# cmdstan-2.33.1       | 46.0 MB   | ##3                                   |   6%
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##2                                   |   6%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##############7                       |  40%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ###############                       |  41%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ####################2                 |  55%
# gcc_impl_linux-64-12 | 49.5 MB   | ##3                                   |   6%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ###############4                      |  42%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ###############6                      |  42%
# cmdstan-2.33.1       | 46.0 MB   | ##6                                   |   7%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #####################3                |  58%
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##4                                   |   7%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ################2                     |  44%
# cmdstan-2.33.1       | 46.0 MB   | ##7                                   |   7%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ######################2               |  60%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ################8                     |  46%
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##5                                   |   7%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #######################               |  62%
# cmdstan-2.33.1       | 46.0 MB   | ##9                                   |   8%
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##6                                   |   7%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #######################9              |  65%
# cmdstan-2.33.1       | 46.0 MB   | ###                                   |   8%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #################5                    |  47%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##################2                   |  49%
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##7                                   |   7%
# cmdstan-2.33.1       | 46.0 MB   | ###2                                  |   9%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##################                    |  49%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##################8                   |  51%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #########################6            |  69%
# cmdstan-2.33.1       | 46.0 MB   | ###3                                  |   9%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##8                                   |   8%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ###################5                  |  53%
# cmdstan-2.33.1       | 46.0 MB   | ###5                                  |  10%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ##########################5           |  72%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##9                                   |   8%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ####################1                 |  54%
# cmdstan-2.33.1       | 46.0 MB   | ###6                                  |  10%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ###########################6          |  75%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ###                                   |   8%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ####################7                 |  56%
# cmdstan-2.33.1       | 46.0 MB   | ###9                                  |  11%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ############################6         |  77%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ###                                   |   8%
# cmdstan-2.33.1       | 46.0 MB   | ####1                                 |  11%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #####################4                |  58%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #############################7        |  80%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ###1                                  |   9%
# cmdstan-2.33.1       | 46.0 MB   | ####3                                 |  12%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ######################                |  60%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ###############################       |  84%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ###2                                  |   9%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ################################2     |  87%
# cmdstan-2.33.1       | 46.0 MB   | ####5                                 |  12%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ######################6               |  61%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #####################9                |  59%
# gcc_impl_linux-64-12 | 49.5 MB   | ###3                                  |   9%
#
# sysroot_linux-64-2.1 | 14.4 MB   | #################################3    |  90%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #######################2              |  63%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ######################4               |  61%
# cmdstan-2.33.1       | 46.0 MB   | #####                                 |  14%
#
# gcc_impl_linux-64-12 | 49.5 MB   | ###4                                  |   9%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #######################8              |  65%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ######################9               |  62%
#
# sysroot_linux-64-2.1 | 14.4 MB   | ###################################9  |  97%
# gcc_impl_linux-64-12 | 49.5 MB   | ###5                                  |  10%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ########################4             |  66%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #######################6              |  64%
# gcc_impl_linux-64-12 | 49.5 MB   | ###6                                  |  10%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #########################             |  68%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | 1                                     |   0%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ########################4             |  66%
# gcc_impl_linux-64-12 | 49.5 MB   | ###7                                  |  10%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | ##                                    |   5%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #########################5            |  69%
# cmdstan-2.33.1       | 46.0 MB   | ######1                               |  17%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ###8                                  |  10%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | ####7                                 |  13%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##########################1           |  71%
# cmdstan-2.33.1       | 46.0 MB   | ######4                               |  18%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ###9                                  |  11%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | ######4                               |  18%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##########################6           |  72%
# cmdstan-2.33.1       | 46.0 MB   | ######8                               |  18%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ####                                  |  11%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | ########9                             |  24%
# cmdstan-2.33.1       | 46.0 MB   | #######1                              |  19%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ###########################1          |  73%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ###########################5          |  74%
#
# gcc_impl_linux-64-12 | 49.5 MB   | ####2                                 |  11%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | ###########3                          |  31%
# cmdstan-2.33.1       | 46.0 MB   | #######4                              |  20%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ############################2         |  76%
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ####3                                 |  12%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | #############5                        |  37%
# cmdstan-2.33.1       | 46.0 MB   | #######7                              |  21%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ############################9         |  78%
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ####4                                 |  12%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | ###############6                      |  42%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #############################5        |  80%
# cmdstan-2.33.1       | 46.0 MB   | #######9                              |  22%
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ####6                                 |  13%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | #################6                    |  48%
# cmdstan-2.33.1       | 46.0 MB   | ########3                             |  22%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #############################1        |  79%
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ####7                                 |  13%
# cmdstan-2.33.1       | 46.0 MB   | ########5                             |  23%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #############################6        |  80%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##############################9       |  84%
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ####9                                 |  13%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##############################1       |  82%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ###############################7      |  86%
# cmdstan-2.33.1       | 46.0 MB   | ########8                             |  24%
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #####1                                |  14%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ################################4     |  88%
# cmdstan-2.33.1       | 46.0 MB   | #########1                            |  25%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##############################6       |  83%
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #####2                                |  14%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #################################1    |  90%
# cmdstan-2.33.1       | 46.0 MB   | #########4                            |  25%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ###############################1      |  84%
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #####4                                |  15%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | #################################9    |  92%
# cmdstan-2.33.1       | 46.0 MB   | #########6                            |  26%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ###############################8      |  86%
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #####6                                |  15%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##################################7   |  94%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ################################3     |  87%
# cmdstan-2.33.1       | 46.0 MB   | #########9                            |  27%
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #####7                                |  16%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ###################################5  |  96%
# cmdstan-2.33.1       | 46.0 MB   | ##########1                           |  27%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #################################     |  89%
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #####9                                |  16%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ####################################2 |  98%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | #################################5    |  91%
# cmdstan-2.33.1       | 46.0 MB   | ##########3                           |  28%
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ######1                               |  17%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | 1                                     |   0%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##################################3   |  93%
# gcc_impl_linux-64-12 | 49.5 MB   | ######3                               |  17%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | 2                                     |   1%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | ##4                                   |   7%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##################################9   |  95%
# cmdstan-2.33.1       | 46.0 MB   | ##########9                           |  30%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ##8                                   |   8%
#
#
#
#
# binutils_impl_linux- | 5.2 MB    | ##################################### | 100%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ###################################5  |  96%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | ####9                                 |  13%
# gcc_impl_linux-64-12 | 49.5 MB   | ######4                               |  18%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ######1                               |  17%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##################################### | 100%
#
#
#
# libstdcxx-devel_linu | 11.1 MB   | ##################################### | 100%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ####################################2 |  98%
# cmdstan-2.33.1       | 46.0 MB   | ###########5                          |  31%
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ######6                               |  18%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ########2                             |  22%
# cmdstan-2.33.1       | 46.0 MB   | ###########8                          |  32%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | #########9                            |  27%
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ######8                               |  19%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ###########3                          |  31%
# cmdstan-2.33.1       | 46.0 MB   | ############2                         |  33%
#
#
# gxx_impl_linux-64-12 | 12.2 MB   | ##################################### | 100%
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #######1                              |  19%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | #############6                        |  37%
# cmdstan-2.33.1       | 46.0 MB   | ############5                         |  34%
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #######2                              |  20%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ################7                     |  45%
#
#
#
#
#
#
#
# ephem-4.1.5          | 1.3 MB    | 4                                     |   1%
# cmdstan-2.33.1       | 46.0 MB   | ############8                         |  35%
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #######4                              |  20%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ###################3                  |  52%
#
#
#
#
#
#
#
# ephem-4.1.5          | 1.3 MB    | #####2                                |  14%
# cmdstan-2.33.1       | 46.0 MB   | #############1                        |  36%
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #######6                              |  21%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | #####################7                |  59%
#
#
#
#
#
#
#
# ephem-4.1.5          | 1.3 MB    | ##########9                           |  30%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | ########################1             |  65%
# gcc_impl_linux-64-12 | 49.5 MB   | #######8                              |  21%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ########################5             |  66%
#
#
#
#
#
#
#
# ephem-4.1.5          | 1.3 MB    | #################9                    |  48%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | ##########################6           |  72%
# gcc_impl_linux-64-12 | 49.5 MB   | #######9                              |  22%
#
#
#
#
#
#
#
# ephem-4.1.5          | 1.3 MB    | #######################1              |  63%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ###########################1          |  73%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | #############################1        |  79%
# gcc_impl_linux-64-12 | 49.5 MB   | ########1                             |  22%
#
#
#
#
#
#
#
# ephem-4.1.5          | 1.3 MB    | ###########################9          |  76%
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ########3                             |  22%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | ################################4     |  88%
#
#
#
#
#
#
#
# ephem-4.1.5          | 1.3 MB    | #################################6    |  91%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ################################3     |  87%
# cmdstan-2.33.1       | 46.0 MB   | ##############3                       |  39%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | ##################################7   |  94%
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ########4                             |  23%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ###################################3  |  96%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# tbb-devel-2021.11.0  | 1.0 MB    | 5                                     |   2%
# gcc_impl_linux-64-12 | 49.5 MB   | ########6                             |  23%
#
#
#
#
#
#
# libgcc-devel_linux-6 | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
# libsanitizer-12.3.0  | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# kernel-headers_linux | 694 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
# tbb-devel-2021.11.0  | 1.0 MB    | ###########4                          |  31%
# gcc_impl_linux-64-12 | 49.5 MB   | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
# kernel-headers_linux | 694 KB    | ##########2                           |  28%
#
#
#
#
#
#
#
#
# tbb-devel-2021.11.0  | 1.0 MB    | ###################5                  |  53%
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ########9                             |  24%
# cmdstan-2.33.1       | 46.0 MB   | ##############9                       |  40%
#
#
#
#
#
#
#
#
#
#
# kernel-headers_linux | 694 KB    | ###################6                  |  53%
#
#
#
#
#
#
#
#
# tbb-devel-2021.11.0  | 1.0 MB    | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
# kernel-headers_linux | 694 KB    | ###########################2          |  74%
# cmdstan-2.33.1       | 46.0 MB   | ###############                       |  41%
#
#
#
#
#
#
#
#
# tbb-devel-2021.11.0  | 1.0 MB    | #################################2    |  90%
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #########2                            |  25%
# cmdstan-2.33.1       | 46.0 MB   | ###############2                      |  41%
#
#
#
#
#
#
#
#
#
#
#
# pymeeus-0.5.12       | 507 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# make-4.3             | 507 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #########4                            |  25%
# cmdstan-2.33.1       | 46.0 MB   | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
# pymeeus-0.5.12       | 507 KB    | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #########5                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
# holidays-0.45        | 341 KB    | #7                                    |   5%
# cmdstan-2.33.1       | 46.0 MB   | ###############7                      |  43%
#
#
#
#
#
#
#
#
#
#
#
# pymeeus-0.5.12       | 507 KB    | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# make-4.3             | 507 KB    | ########################5             |  66%
#
#
#
#
#
#
#
#
#
# prophet-1.1.5        | 847 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# holidays-0.45        | 341 KB    | ########################3             |  66%
# gcc_impl_linux-64-12 | 49.5 MB   | #########7                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.2.2      | 69 KB     | ########5                             |  23%
# cmdstan-2.33.1       | 46.0 MB   | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# convertdate-2.4.0    | 38 KB     | ###############5                      |  42%
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_linux-64-12.3.0  | 30 KB     | ###################5                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_linux-64-12.3.0  | 29 KB     | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lunarcalendar-0.0.9  | 20 KB     | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_linux-64-2. | 28 KB     | ####################9                 |  57%
# cmdstan-2.33.1       | 46.0 MB   | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##########                            |  27%
#
#
#
#
#
#
#
#
# tbb-devel-2021.11.0  | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# kernel-headers_linux | 694 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# kernel-headers_linux | 694 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# make-4.3             | 507 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# make-4.3             | 507 KB    | ##################################### | 100%
# cmdstan-2.33.1       | 46.0 MB   | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.2.2      | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-12 | 49.5 MB   | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# convertdate-2.4.0    | 38 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# convertdate-2.4.0    | 38 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_linux-64-12.3.0  | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gcc_linux-64-12.3.0  | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lunarcalendar-0.0.9  | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lunarcalendar-0.0.9  | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_linux-64-12.3.0  | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_linux-64-12.3.0  | 29 KB     | ##################################### | 100%
# gcc_impl_linux-64-12 | 49.5 MB   | ##########3                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stanio-0.5.0         | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_linux-64-2. | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# binutils_linux-64-2. | 28 KB     | ##################################### | 100%
# gcc_impl_linux-64-12 | 49.5 MB   | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
# holidays-0.45        | 341 KB    | ##################################### | 100%
# gcc_impl_linux-64-12 | 49.5 MB   | ##########6                           |  29%
# gcc_impl_linux-64-12 | 49.5 MB   | ##########8                           |  29%
# gcc_impl_linux-64-12 | 49.5 MB   | ###########                           |  30%
# gcc_impl_linux-64-12 | 49.5 MB   | ###########3                          |  31%
# gcc_impl_linux-64-12 | 49.5 MB   | ###########8                          |  32%
# gcc_impl_linux-64-12 | 49.5 MB   | ############1                         |  33%
# gcc_impl_linux-64-12 | 49.5 MB   | ############4                         |  34%
# gcc_impl_linux-64-12 | 49.5 MB   | ############7                         |  35%
# gcc_impl_linux-64-12 | 49.5 MB   | #############1                        |  36%
# gcc_impl_linux-64-12 | 49.5 MB   | #############4                        |  36%
# gcc_impl_linux-64-12 | 49.5 MB   | #############8                        |  37%
# gcc_impl_linux-64-12 | 49.5 MB   | ##############1                       |  38%
# gcc_impl_linux-64-12 | 49.5 MB   | ##############4                       |  39%
# gcc_impl_linux-64-12 | 49.5 MB   | ##############8                       |  40%
# gcc_impl_linux-64-12 | 49.5 MB   | ###############1                      |  41%
# gcc_impl_linux-64-12 | 49.5 MB   | ###############5                      |  42%
# gcc_impl_linux-64-12 | 49.5 MB   | ###############8                      |  43%
# gcc_impl_linux-64-12 | 49.5 MB   | ################2                     |  44%
# gcc_impl_linux-64-12 | 49.5 MB   | ################6                     |  45%
# gcc_impl_linux-64-12 | 49.5 MB   | #################                     |  46%
# gcc_impl_linux-64-12 | 49.5 MB   | #################3                    |  47%
# gcc_impl_linux-64-12 | 49.5 MB   | #################7                    |  48%
# gcc_impl_linux-64-12 | 49.5 MB   | ##################                    |  49%
# gcc_impl_linux-64-12 | 49.5 MB   | ##################4                   |  50%
# gcc_impl_linux-64-12 | 49.5 MB   | ##################8                   |  51%
# gcc_impl_linux-64-12 | 49.5 MB   | ###################2                  |  52%
# gcc_impl_linux-64-12 | 49.5 MB   | ###################6                  |  53%
# gcc_impl_linux-64-12 | 49.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from prophet import Prophet
from prophet.diagnostics import cross_validation

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/home/leejieun/workspace/kaggle-notebooks/datasets/tcashion/tokyo-wholesale-tuna-prices/tokyo_wholesale_tuna_prices.csv")

# %%
df.columns
# Out:
# Index(['year', 'month', 'value', 'species', 'state', 'fleet', 'measure'], dtype='object')

# %%
fisheries = df[['species', 'state', 'fleet']].drop_duplicates()
fisheries['id'] = [x for x in range(1, len(fisheries)+1)]
df = df.merge(fisheries)

# %%
id_number = 1
measure = 'Price'
temp = df.loc[((df['id'] == id_number) & (df['measure'] == measure))]
temp = temp.reset_index(drop= True)
temp['ds'] = df['year'] + ((df['month'] -1) / 12)
temp = temp.rename(columns={'value': 'y'})
temp['ds'] = [datetime.date(year, month, 1) for year, month in zip(temp['year'], temp['month'])]
prophet_df= temp[['ds', 'y']]

# %%
model = Prophet()
model.fit(prophet_df)
df_cv = cross_validation(
    model,
    initial=f'{365 * 5} days',
    period='365 days',
    horizon='365 days'
)
# Out:
# 14:36:28 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:28 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/8 [00:00<?, ?it/s]
# 14:36:28 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:28 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:28 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:28 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:28 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] done processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:36:29 - cmdstanpy - INFO - Chain [1] done processing

# %%
df_cv.tail()
# Out:
#            ds         yhat   yhat_lower   yhat_upper            y     cutoff
# 91 2016-08-01  2901.844066  2443.723285  3366.413346  3234.093635 2015-12-02
# 92 2016-09-01  3400.659185  2893.720751  3831.352776  3434.789383 2015-12-02
# 93 2016-10-01  3608.884953  3131.807497  4047.704280  3537.157636 2015-12-02
# 94 2016-11-01  3883.284209  3426.047598  4357.983967  3889.000000 2015-12-02
# 95 2016-12-01  4303.002774  3833.310747  4783.150039  3897.530718 2015-12-02

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape')

# %%
future_df = model.make_future_dataframe(12, freq='MS')
forecast_df = model.predict(future_df)

# %%
model.plot(forecast_df)
