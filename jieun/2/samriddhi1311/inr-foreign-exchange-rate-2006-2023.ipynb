# %% [markdown]
# ## INR 환율 2000/2006 - 2023
# 2000 - 2023과 2006 - 2023의 일일 환율

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from datetime import date
import time
import datetime as dt

import random
import math

# %%
df = pd.read_csv('/home/leejieun/workspace/kaggle-notebooks/datasets/samriddhi1311/inr-foreign-exchange-rate-2006-2023/ForEx Rates 2006.csv')

# %%
df.shape
# Out:
# (4695, 36)

# %%
df.describe()
# Out:
#                USD          AUS          CAN          SWF          DKK  \
# count  4695.000000  4695.000000  4695.000000  4695.000000  4695.000000
# mean     60.430864    48.023215    50.618290    61.907912     9.838732
# std      12.929086     7.628518     7.065958    16.576098     1.383992
# min      39.075000    29.974000    36.244000    32.596000     7.030500
# 25%      46.770000    42.291000    44.521500    45.652000     8.761750
# 50%      62.490000    50.154000    51.597000    66.255000     9.870300
# 75%      71.152500    54.140000    55.745000    71.938000    10.955050
# max      83.426000    61.515000    65.613000    98.871000    12.401100
#
#                EUR          GBP          HKD          IDR          JPY  ...  \
# count  4695.000000  4695.000000  4695.000000  4340.000000  4695.000000  ...
# mean     73.913137    88.626593     7.761465     0.035401    27.193924  ...
# std       9.376571    10.034709     1.647154     0.116727    30.981567  ...
# ...

# %%
df.tail()
# Out:
#             Date     USD     AUS     CAN     SWF     DKK      EUR     GBP  \
# 4690  06-01-2006  44.320  33.424  38.031  34.894  7.2225  57.8200  77.743
# 4691  05-01-2006  44.600  33.332  38.374  34.945  7.2347  58.0415  77.651
# 4692  04-01-2006  44.705  33.394  38.915  35.014  7.2613  58.2295  77.555
# 4693  03-01-2006  44.965  33.272  38.899  34.828  7.2410  58.0085  77.340
# 4694  02-01-2006  45.075  33.047  38.659  34.303  7.1437  58.1045  77.160
#
#          HKD  IDR  ...  ISK     MXN  PHP  PKR    PLN     RUB    SAR    TRY  \
# 4690  5.7162  NaN  ...  NaN  4.1964  NaN  NaN  14.15  1.5459  11.82  33.35
# 4691  5.7520  NaN  ...  NaN  4.1957  NaN  NaN  14.17  1.5556  11.89  33.42
# 4692  5.7604  NaN  ...  NaN  4.2256  NaN  NaN  14.23  1.5554  11.92  33.52
# 4693  5.7992  NaN  ...  NaN  4.2279  NaN  NaN  14.12  1.5645  11.99  33.48
# 4694  5.8131  NaN  ...  NaN  4.2359  NaN  NaN  13.80  1.5683  12.02  33.36
#
#       VEF       BHD
# 4690  NaN  117.5830
# 4691  NaN  118.3225
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4695 entries, 0 to 4694
# Data columns (total 36 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4695 non-null   object
#  1   USD     4695 non-null   float64
#  2   AUS     4695 non-null   float64
#  3   CAN     4695 non-null   float64
#  4   SWF     4695 non-null   float64
#  5   DKK     4695 non-null   float64
#  6   EUR     4695 non-null   float64
#  7   GBP     4695 non-null   float64
#  8   HKD     4695 non-null   float64
#  9   IDR     4340 non-null   float64
#  10  JPY     4695 non-null   float64
#  11  KRW     4241 non-null   float64
#  12  MYR     4694 non-null   float64
#  13  NOK     4695 non-null   float64
#  14  NZD     4695 non-null   float64
#  15  SEK     4695 non-null   float64
#  16  SGD     4695 non-null   float64
#  17  THB     4695 non-null   float64
#  18  TWD     4695 non-null   float64
#  19  ZAR     4695 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Date       0
# USD        0
# AUS        0
# CAN        0
# SWF        0
# DKK        0
# EUR        0
# GBP        0
# HKD        0
# IDR      355
# JPY        0
# KRW      454
# MYR        1
# NOK        0
# NZD        0
# SEK        0
# SGD        0
# THB        0
# TWD        0
# ZAR        0
# AED        0
# ARS        0
# BRL        0
# CNY        0
# HUF        0
# ILS     1036
# ISK     1036
# MXN        0
# PHP     1036
# PKR      304
# PLN        0
# RUB        0
# SAR        0
# TRY        0
# VEF     4673
# BHD        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date       0
# USD        0
# AUS        0
# CAN        0
# SWF        0
# DKK        0
# EUR        0
# GBP        0
# HKD        0
# IDR      355
# JPY        0
# KRW      454
# MYR        1
# NOK        0
# NZD        0
# SEK        0
# SGD        0
# THB        0
# TWD        0
# ZAR        0
# AED        0
# ARS        0
# BRL        0
# CNY        0
# HUF        0
# ILS     1036
# ISK     1036
# MXN        0
# PHP     1036
# PKR      304
# PLN        0
# RUB        0
# SAR        0
# TRY        0
# VEF     4673
# BHD        0
# dtype: int64

# %%
print("Number of records:", len(df))
print(f"Number of days between {date(2006, 1, 1)} and {date(2023, 8, 31)}: {(date(2023, 8, 31) - date(2006, 1, 1)).days}")
print(f'Percentage Data available: {round(100*len(df)/((date(2023, 8, 31) - date(2006, 1, 1)).days), 2)}')
# Out:
# Number of records: 4695
# Number of days between 2006-01-01 and 2023-08-31: 6451
# Percentage Data available: 72.78

# %%
df.sort_values('Date', inplace=True)

# %%
df.head()
# Out:
#             Date     USD     AUS     CAN     SWF     DKK      EUR     GBP  \
# 4434  01-01-2007  44.115  34.842  37.838  36.193  7.8083  61.2695  85.590
# 4173  01-01-2008  39.415  34.541  39.723  34.778  7.7115  65.3210  77.329
# 3911  01-01-2009  48.750  34.242  39.936  45.676  9.1565  65.8709  71.117
# 3650  01-01-2010  46.615  41.825  44.309  45.047  8.9741  60.8910  72.281
# 2868  01-01-2013  54.685  56.817  55.048  59.680  9.6690  71.8605  83.923
#
#          HKD     IDR  ...     ISK     MXN     PHP     PKR    PLN     RUB  \
# 4434  5.6714     NaN  ...     NaN  4.0840     NaN     NaN  15.19  1.6767
# 4173  5.0537  0.4910  ...     NaN  3.6126     NaN  0.5489  15.98  1.6040
# 3911  6.2902  0.0052  ...     NaN  3.5173     NaN  0.5183  16.53  1.6720
# 3650  6.0114  0.0057  ...  0.3767  3.5595  1.0045  0.5829  16.36  1.5378
# 2868  7.0555  0.0051  ...  0.4271  4.2475  1.3330  0.5981  17.70  1.7878
#
#         SAR    TRY  VEF       BHD
# 4434  11.76  31.17  NaN  117.0140
# ...

# %%
#df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
#df = df.set_index('Date')

# %%
df.head()
# Out:
#                USD     AUS     CAN     SWF     DKK      EUR     GBP     HKD  \
# Date
# 2007-01-01  44.115  34.842  37.838  36.193  7.8083  61.2695  85.590  5.6714
# 2008-01-01  39.415  34.541  39.723  34.778  7.7115  65.3210  77.329  5.0537
# 2009-01-01  48.750  34.242  39.936  45.676  9.1565  65.8709  71.117  6.2902
# 2010-01-01  46.615  41.825  44.309  45.047  8.9741  60.8910  72.281  6.0114
# 2013-01-01  54.685  56.817  55.048  59.680  9.6690  71.8605  83.923  7.0555
#
#                IDR     JPY  ...     ISK     MXN     PHP     PKR    PLN  \
# Date                        ...
# 2007-01-01     NaN  0.3679  ...     NaN  4.0840     NaN     NaN  15.19
# 2008-01-01  0.4910  0.5323  ...     NaN  3.6126     NaN  0.5489  15.98
# 2009-01-01  0.0052  0.5054  ...     NaN  3.5173     NaN  0.5183  16.53
# 2010-01-01  0.0057  0.5434  ...  0.3767  3.5595  1.0045  0.5829  16.36
# 2013-01-01  0.0051  0.6068  ...  0.4271  4.2475  1.3330  0.5981  17.70
#
# ...

# %%
empty_cols = [col for col in df.columns
              if 100*df[col].isnull().sum()/len(df) >8]
print(empty_cols)
print(100* df[empty_cols].isnull().sum()/len(df))
# Out:
# ['KRW', 'ILS', 'ISK', 'PHP', 'VEF']
# KRW     9.669862
# ILS    22.066028
# ISK    22.066028
# PHP    22.066028
# VEF    99.531416
# dtype: float64

# %%
df.drop('VEF', axis=1, inplace=True)

# %%
df = df.copy()

# %%
df
# Out:
#                USD     AUS     CAN     SWF      DKK      EUR      GBP     HKD  \
# Date
# 2007-01-01  44.115  34.842  37.838  36.193   7.8083  61.2695   85.590  5.6714
# 2008-01-01  39.415  34.541  39.723  34.778   7.7115  65.3210   77.329  5.0537
# 2009-01-01  48.750  34.242  39.936  45.676   9.1565  65.8709   71.117  6.2902
# 2010-01-01  46.615  41.825  44.309  45.047   8.9741  60.8910   72.281  6.0114
# 2013-01-01  54.685  56.817  55.048  59.680   9.6690  71.8605   83.923  7.0555
# ...            ...     ...     ...     ...      ...      ...      ...     ...
# 2015-12-31  66.208  48.200  47.837  66.073   9.6341  70.5260   97.686  8.5427
# 2018-12-31  69.570  49.033  51.014  70.874  10.6823  82.9390   88.738  8.8817
# 2019-12-31  71.355  50.095  54.940  73.693  10.7068  79.2550   94.660  9.1585
# 2020-12-31  73.054  56.194  57.342  82.480  11.9861  86.5090   99.862  9.4211
# 2021-12-31  74.486  54.063  58.923  81.599  11.3838  86.9370  100.746  9.5518
#
# ...

# %%
df = df.interpolate(method='bfill') # 결측치의 바로 뒤의 값으로 채운다
df.isnull().sum()
# Out:
# USD    0
# AUS    0
# CAN    0
# SWF    0
# DKK    0
# EUR    0
# GBP    0
# HKD    0
# IDR    0
# JPY    0
# KRW    0
# MYR    0
# NOK    0
# NZD    0
# SEK    0
# SGD    0
# THB    0
# TWD    0
# ZAR    0
# AED    0
# ARS    0
# BRL    0
# CNY    0
# HUF    0
# ILS    0
# ISK    0
# MXN    0
# PHP    0
# PKR    0
# PLN    0
# RUB    0
# SAR    0
# TRY    0
# BHD    0
# dtype: int64

# %%
df.head()
# Out:
#                USD     AUS     CAN     SWF     DKK      EUR     GBP     HKD  \
# Date
# 2007-01-01  44.115  34.842  37.838  36.193  7.8083  61.2695  85.590  5.6714
# 2008-01-01  39.415  34.541  39.723  34.778  7.7115  65.3210  77.329  5.0537
# 2009-01-01  48.750  34.242  39.936  45.676  9.1565  65.8709  71.117  6.2902
# 2010-01-01  46.615  41.825  44.309  45.047  8.9741  60.8910  72.281  6.0114
# 2013-01-01  54.685  56.817  55.048  59.680  9.6690  71.8605  83.923  7.0555
#
#                IDR     JPY  ...    ILS     ISK     MXN     PHP     PKR    PLN  \
# Date                        ...
# 2007-01-01  0.4910  0.3679  ...  12.29  0.3767  4.0840  1.0045  0.5489  15.19
# 2008-01-01  0.4910  0.5323  ...  12.29  0.3767  3.6126  1.0045  0.5489  15.98
# 2009-01-01  0.0052  0.5054  ...  12.29  0.3767  3.5173  1.0045  0.5183  16.53
# 2010-01-01  0.0057  0.5434  ...  12.29  0.3767  3.5595  1.0045  0.5829  16.36
# 2013-01-01  0.0051  0.6068  ...  14.64  0.4271  4.2475  1.3330  0.5981  17.70
#
# ...

# %%
#empty_cols.remove('VEF')

#plt.plot(data=df[empty_cols],figsize=(20,5))

sns.lineplot(df[empty_cols])
# Out:
# <Axes: xlabel='Date'>

# %%
fig , ax = plt.subplots(1, 1, figsize=(20,10))
sns.lineplot(df[:])
# Out:
# <Axes: xlabel='Date'>

# %%
name = 'USD'
plt.plot(df[name])
plt.show()

# %%
data= pd.DataFrame(df[name])
data.head()
# Out:
#                USD
# Date
# 2007-01-01  44.115
# 2008-01-01  39.415
# 2009-01-01  48.750
# 2010-01-01  46.615
# 2013-01-01  54.685
