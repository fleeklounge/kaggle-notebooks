# %% [markdown]
# ## 심벌즈 투자
# 미국에 기반을 둔 글로벌 투자 및 자산 관리자의 거래 데이터.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/leejieun/workspace/kaggle-notebooks/datasets/mustafakeser4/cymbal-investments/cymbal_investments_trade_capture_report.csv')

# %%
df.head()
# Out:
#                  SendingTime   TargetCompID SenderCompID Symbol  Quantity  \
# 0  2020-05-18 17:27:57+00:00  MOMOES-COMPID         MDOC   ESM0         1
# 1  2020-05-18 17:29:14+00:00  MOMOES-COMPID         MDOC   ESM0         1
# 2  2020-05-18 18:28:40+00:00  MOMOES-COMPID         MDOC   ESM0         1
# 3  2020-05-18 18:30:03+00:00  MOMOES-COMPID         MDOC   ESM0         1
# 4  2020-05-18 20:10:16+00:00  MOMOES-COMPID         MDOC   ESM0         1
#
#                        TransactTime  StrikePrice    LastPx  \
# 0  2020-05-18 17:27:58.165000+00:00     2954.125  2953.125
# 1  2020-05-18 17:29:14.884000+00:00     2953.625  2953.875
# 2  2020-05-18 18:28:41.183000+00:00     2953.875  2953.625
# 3  2020-05-18 18:30:04.163000+00:00     2954.875  2953.375
# 4  2020-05-18 20:10:17.201000+00:00     2948.125  2948.875
#
#                        MaturityDate                           TradeReportID  \
# 0  2020-05-18 17:28:58.165000+00:00  50bfaefb-53f3-4454-92af-f2fc11ab9176-0
# ...

# %%
df.shape
# Out:
# (1222562, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222562 entries, 0 to 1222561
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   SendingTime    1222562 non-null  object
#  1   TargetCompID   1222562 non-null  object
#  2   SenderCompID   1222562 non-null  object
#  3   Symbol         1222562 non-null  object
#  4   Quantity       1222562 non-null  int64
#  5   TransactTime   1222562 non-null  object
#  6   StrikePrice    1222562 non-null  float64
#  7   LastPx         1222562 non-null  float64
#  8   MaturityDate   1222562 non-null  object
#  9   TradeReportID  1222562 non-null  object
#  10  TradeDate      1222562 non-null  object
#  11  CFICode        1222562 non-null  object
#  12  Side           1222562 non-null  object
#  13  OrderID        1222562 non-null  object
#  14  PartyID        1222562 non-null  object
#  15  PartyIDSource  1222562 non-null  object
# ...

# %%
df['Symbol'].value_counts()
# Out:
# Symbol
# NQU0     207415
# ESU0     191463
# NQZ0     156552
# ESZ0     147993
# NQM0      80200
# BTCV0     69689
# ESM0      65423
# BTCU0     62066
# BTCQ0     61347
# BTCN0     60765
# BTCZ0     56424
# BTCM0     38407
# BTCK0     24818
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         Quantity   StrikePrice        LastPx
# count  1222562.0  1.222562e+06  1.222562e+06
# mean         1.0  8.587711e+03  8.587700e+03
# std          0.0  3.961206e+03  3.961195e+03
# min          1.0  2.904625e+03  2.904875e+03
# 25%          1.0  3.445000e+03  3.445125e+03
# 50%          1.0  1.001138e+04  1.001138e+04
# 75%          1.0  1.144638e+04  1.144662e+04
# max          1.0  1.906500e+04  1.905000e+04

# %%
df.hist(bins=50, figsize=(15,8))
plt.show()

# %%
df.head()
# Out:
#                  SendingTime   TargetCompID SenderCompID Symbol  Quantity  \
# 0  2020-05-18 17:27:57+00:00  MOMOES-COMPID         MDOC   ESM0         1
# 1  2020-05-18 17:29:14+00:00  MOMOES-COMPID         MDOC   ESM0         1
# 2  2020-05-18 18:28:40+00:00  MOMOES-COMPID         MDOC   ESM0         1
# 3  2020-05-18 18:30:03+00:00  MOMOES-COMPID         MDOC   ESM0         1
# 4  2020-05-18 20:10:16+00:00  MOMOES-COMPID         MDOC   ESM0         1
#
#                        TransactTime  StrikePrice    LastPx  \
# 0  2020-05-18 17:27:58.165000+00:00     2954.125  2953.125
# 1  2020-05-18 17:29:14.884000+00:00     2953.625  2953.875
# 2  2020-05-18 18:28:41.183000+00:00     2953.875  2953.625
# 3  2020-05-18 18:30:04.163000+00:00     2954.875  2953.375
# 4  2020-05-18 20:10:17.201000+00:00     2948.125  2948.875
#
#                        MaturityDate                           TradeReportID  \
# 0  2020-05-18 17:28:58.165000+00:00  50bfaefb-53f3-4454-92af-f2fc11ab9176-0
# ...
