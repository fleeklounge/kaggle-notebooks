# %% [markdown]
# ## 온라인 소매 거래 데이터
# 영국 온라인 소매 판매 및 고객 거래 데이터

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/leejieun/kaggle-notebooks/datasets/thedevastator/online-retail-transaction-data/online_retail.csv')

# %%
df
# Out:
#          index InvoiceNo StockCode                          Description  \
# 0            0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1            1    536365     71053                  WHITE METAL LANTERN
# 2            2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3            3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4            4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...        ...       ...       ...                                  ...
# 541904  541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905  541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906  541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907  541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908  541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
#         Quantity      InvoiceDate  UnitPrice  CustomerID         Country
# 0              6   12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1              6   12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2              8   12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3              6   12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4              6   12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...          ...              ...        ...         ...             ...
# 541904        12  12/9/2011 12:50       0.85     12680.0          France
# 541905         6  12/9/2011 12:50       2.10     12680.0          France
# 541906         4  12/9/2011 12:50       4.15     12680.0          France
# 541907         4  12/9/2011 12:50       4.15     12680.0          France
# 541908         3  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 9 columns]

# %%
df.shape
# Out:
# (541909, 9)

# %%
df.head()
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#          index InvoiceNo StockCode                      Description  Quantity  \
# 541904  541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905  541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906  541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   index        541909 non-null  int64
#  1   InvoiceNo    541909 non-null  object
#  2   StockCode    541909 non-null  object
#  3   Description  540455 non-null  object
#  4   Quantity     541909 non-null  int64
#  5   InvoiceDate  541909 non-null  object
#  6   UnitPrice    541909 non-null  float64
#  7   CustomerID   406829 non-null  float64
#  8   Country      541909 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 37.2+ MB

# %%
df.isna().sum()
# Out:
# index               0
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# index               0
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.describe()
# Out:
#                index       Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  541909.000000  406829.000000
# mean   270954.000000       9.552250       4.611114   15287.690570
# std    156435.797851     218.081158      96.759853    1713.600303
# min         0.000000  -80995.000000  -11062.060000   12346.000000
# 25%    135477.000000       1.000000       1.250000   13953.000000
# 50%    270954.000000       3.000000       2.080000   15152.000000
# 75%    406431.000000      10.000000       4.130000   16791.000000
# max    541908.000000   80995.000000   38970.000000   18287.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['index'], inplace=True)

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
len(df['Description'].unique())
# Out:
# 4224

# %%
conda install plotly
# Out:
# Channels:
#  - conda-forge
#  - apple
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/leejieun/miniforge3/envs/ai
#
#   added / updated specs:
#     - plotly
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     plotly-5.19.0              |     pyhd8ed1ab_0         5.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   plotly             conda-forge/noarch::plotly-5.19.0-pyhd8ed1ab_0
#   tenacity           conda-forge/noarch::tenacity-8.2.3-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
df['Description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Most_buyed_product = df.groupby(by='Description').agg({'Quantity':'sum'}).sort_values(by='Quantity', ascending=False).reset_index().head(15)
Most_buyed_product
# Out:
#                            Description  Quantity
# 0    WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847
# 1              JUMBO BAG RED RETROSPOT     47363
# 2        ASSORTED COLOUR BIRD ORNAMENT     36381
# 3                       POPCORN HOLDER     36334
# 4      PACK OF 72 RETROSPOT CAKE CASES     36039
# 5   WHITE HANGING HEART T-LIGHT HOLDER     35317
# 6                   RABBIT NIGHT LIGHT     30680
# 7              MINI PAINT SET VINTAGE      26437
# 8           PACK OF 12 LONDON TISSUES      26315
# 9   PACK OF 60 PINK PAISLEY CAKE CASES     24753
# 10     VICTORIAN GLASS HANGING T-LIGHT     23854
# 11           ASSORTED COLOURS SILK FAN     23082
# 12                 BROCADE RING PURSE      23053
# 13              RED  HARMONICA IN BOX      21866
# 14             JUMBO BAG PINK POLKADOT     21009

# %%
fig = px.bar(Most_buyed_product, x='Quantity', y='Description', title='Top 15 Most Buyed Product')
fig.show()

# %%
top_products_countrywise = df.groupby(['Country', 'Description']).agg({'Quantity':'sum'}).reset_index()
top_products_countrywise
# Out:
#            Country                    Description  Quantity
# 0        Australia              DOLLY GIRL BEAKER       200
# 1        Australia    I LOVE LONDON MINI BACKPACK         4
# 2        Australia         10 COLOUR SPACEBOY PEN        48
# 3        Australia  12 PENCIL SMALL TUBE WOODLAND       384
# 4        Australia      12 PENCILS TALL TUBE POSY       252
# ...            ...                            ...       ...
# 20171  Unspecified           WRAP POPPIES  DESIGN        25
# 20172  Unspecified          WRAP SUKI AND FRIENDS        25
# 20173  Unspecified    WRAP VINTAGE PETALS  DESIGN        25
# 20174  Unspecified               WRAP WEDDING DAY        25
# 20175  Unspecified    ZINC METAL HEART DECORATION         2
#
# [20176 rows x 3 columns]

# %%
countries = list(df['Country'].unique())
countries
# Out:
# ['United Kingdom',
#  'France',
#  'Australia',
#  'Netherlands',
#  'Germany',
#  'Norway',
#  'EIRE',
#  'Switzerland',
#  'Spain',
#  'Poland',
#  'Portugal',
#  'Italy',
#  'Belgium',
#  'Lithuania',
#  'Japan',
#  'Iceland',
#  'Channel Islands',
#  'Denmark',
#  'Cyprus',
#  'Sweden',
#  'Austria',
#  'Israel',
#  'Finland',
#  'Bahrain',
#  'Greece',
#  'Hong Kong',
#  'Singapore',
#  'Lebanon',
#  'United Arab Emirates',
#  'Saudi Arabia',
#  'Czech Republic',
#  'Canada',
#  'Unspecified',
#  'Brazil',
#  'USA',
#  'European Community',
#  'Malta',
#  'RSA']

# %%
conda install wordcloud
# Out:
# Channels:
#  - conda-forge
#  - apple
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/leejieun/miniforge3/envs/ai
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     wordcloud-1.9.3            |   py39h17cfd9d_1         166 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         166 KB
#
# The following NEW packages will be INSTALLED:
#
#   wordcloud          conda-forge/osx-arm64::wordcloud-1.9.3-py39h17cfd9d_1
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

# %%
text=[]
for i in countries:
    i = i.replace(' ', '')
    text.append(i)
text=','.join(text)
wordcloud = WordCloud(width=1600, height=1200, background_color='white').generate(text)
plt.title('Countries')
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
df['Total_amount_paid'] = df['Quantity']*df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total_amount_paid
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom              15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom              20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom              22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom              20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom              20.34

# %%
conda install geopandas matplotlib
# Out:
# Channels:
#  - conda-forge
#  - apple
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/leejieun/miniforge3/envs/ai
#
#   added / updated specs:
#     - geopandas
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blosc-1.21.5               |       hc338f07_0          33 KB  conda-forge
#     boost-cpp-1.78.0           |       hf1d6563_2        14.5 MB  conda-forge
#     branca-0.7.1               |     pyhd8ed1ab_0          29 KB  conda-forge
#     cairo-1.16.0               |    h73a0509_1014         1.3 MB  conda-forge
#     cffi-1.16.0                |   py39he153c15_0         226 KB  conda-forge
#     cfitsio-4.1.0              |       hd4f5c17_0         1.2 MB  conda-forge
#     cligj-0.7.2                |     pyhd8ed1ab_1          10 KB  conda-forge
#     curl-8.1.2                 |       h912dcd9_0         143 KB  conda-forge
#     fiona-1.8.21               |   py39hf45f784_2         909 KB  conda-forge
#     folium-0.16.0              |     pyhd8ed1ab_0          72 KB  conda-forge
#     freexl-1.0.6               |       h1a8c8d9_1          44 KB  conda-forge
#     gdal-3.5.1                 |   py39hedf9a19_1         1.8 MB  conda-forge
#     geopandas-0.14.3           |     pyhd8ed1ab_0           7 KB  conda-forge
#     geopandas-base-0.14.3      |     pyha770c72_0         997 KB  conda-forge
#     geos-3.11.0                |       h9a09cb3_0         1.3 MB  conda-forge
#     geotiff-1.7.1              |       hc898e3f_3         126 KB  conda-forge
#     hdf4-4.2.15                |       h1a38d6a_5         926 KB  conda-forge
#     icu-70.1                   |       h6b3803e_0        13.3 MB  conda-forge
#     jpeg-9e                    |       he4db4b2_2         259 KB  conda-forge
#     json-c-0.16                |       hc449e50_0          72 KB  conda-forge
#     kealib-1.4.14              |       hca62043_4         152 KB  conda-forge
#     krb5-1.20.1                |       h69eda48_0         1.0 MB  conda-forge
#     lcms2-2.14                 |       h8193b64_0         227 KB  conda-forge
#     libcurl-8.1.2              |       h912dcd9_0         338 KB  conda-forge
#     libdap4-3.20.6             |       h8510809_2         2.1 MB  conda-forge
#     libdeflate-1.14            |       h1a8c8d9_0          60 KB  conda-forge
#     libgdal-3.5.1              |       hb972c36_1         8.3 MB  conda-forge
#     libjpeg-turbo-2.1.4        |       h1a8c8d9_0         835 KB  conda-forge
#     libkml-1.3.0               |    h4f02115_1016         409 KB  conda-forge
#     libnetcdf-4.8.1            |nompi_h96a3436_102         1.3 MB  conda-forge
#     libnghttp2-1.58.0          |       ha4dd798_0         551 KB  conda-forge
#     libpq-14.5                 |       h1a28acd_5         2.2 MB  conda-forge
#     librttopo-1.1.0            |      h275bb25_11         202 KB  conda-forge
#     libspatialindex-1.9.3      |       hbdafb3b_4         376 KB  conda-forge
#     libspatialite-5.0.1        |      h97b496e_19         3.9 MB  conda-forge
#     libtiff-4.4.0              |       heb92581_5         421 KB  conda-forge
#     libxcb-1.13                |    h9b22ae9_1004         345 KB  conda-forge
#     libxml2-2.10.3             |       h67585b2_4         584 KB  conda-forge
#     libzip-1.10.1              |       ha0bc3c6_3         125 KB  conda-forge
#     mapclassify-2.6.1          |     pyhd8ed1ab_0          38 KB  conda-forge
#     munch-4.0.0                |     pyhd8ed1ab_0          15 KB  conda-forge
#     nspr-4.35                  |       hb7217d7_0         216 KB  conda-forge
#     nss-3.98                   |       h5ce2875_0         1.7 MB  conda-forge
#     openjpeg-2.5.0             |       h5d4e404_1         393 KB  conda-forge
#     openssl-3.1.5              |       h0d3ecfb_0         2.1 MB  conda-forge
#     pcre-8.45                  |       hbdafb3b_0         230 KB  conda-forge
#     pillow-9.2.0               |   py39h139752e_3        45.2 MB  conda-forge
#     poppler-22.04.0            |       h4f9e0c6_3         1.6 MB  conda-forge
#     poppler-data-0.4.12        |       hd8ed1ab_0         2.2 MB  conda-forge
#     postgresql-14.5            |       h45c140d_5         3.9 MB  conda-forge
#     proj-9.0.1                 |       h4c79c2b_1         2.7 MB  conda-forge
#     pyproj-3.4.0               |   py39h4b6117f_0         423 KB  conda-forge
#     rtree-1.2.0                |   py39hb28b0e7_0          49 KB  conda-forge
#     shapely-1.8.5              |   py39hda9c22c_1         344 KB  conda-forge
#     snappy-1.1.10              |       h17c5cce_0          33 KB  conda-forge
#     tiledb-2.9.4               |       h824fbfd_0         3.8 MB  conda-forge
#     tzcode-2024a               |       h93a5062_0          62 KB  conda-forge
#     uriparser-0.9.7            |       h13dd4ca_1          40 KB  conda-forge
#     xerces-c-3.2.4             |       h627aa08_1         1.4 MB  conda-forge
#     xyzservices-2023.10.1      |     pyhd8ed1ab_0          35 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       126.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   blosc              conda-forge/osx-arm64::blosc-1.21.5-hc338f07_0
#   boost-cpp          conda-forge/osx-arm64::boost-cpp-1.78.0-hf1d6563_2
#   branca             conda-forge/noarch::branca-0.7.1-pyhd8ed1ab_0
#   bzip2              conda-forge/osx-arm64::bzip2-1.0.8-h93a5062_5
#   cairo              conda-forge/osx-arm64::cairo-1.16.0-h73a0509_1014
#   cfitsio            conda-forge/osx-arm64::cfitsio-4.1.0-hd4f5c17_0
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   click-plugins      conda-forge/noarch::click-plugins-1.1.1-py_0
#   cligj              conda-forge/noarch::cligj-0.7.2-pyhd8ed1ab_1
#   curl               conda-forge/osx-arm64::curl-8.1.2-h912dcd9_0
#   expat              conda-forge/osx-arm64::expat-2.6.2-hebf3989_0
#   fiona              conda-forge/osx-arm64::fiona-1.8.21-py39hf45f784_2
#   folium             conda-forge/noarch::folium-0.16.0-pyhd8ed1ab_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_1
#   fontconfig         conda-forge/osx-arm64::fontconfig-2.14.2-h82840c6_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freexl             conda-forge/osx-arm64::freexl-1.0.6-h1a8c8d9_1
#   gdal               conda-forge/osx-arm64::gdal-3.5.1-py39hedf9a19_1
#   geopandas          conda-forge/noarch::geopandas-0.14.3-pyhd8ed1ab_0
#   geopandas-base     conda-forge/noarch::geopandas-base-0.14.3-pyha770c72_0
#   geos               conda-forge/osx-arm64::geos-3.11.0-h9a09cb3_0
#   geotiff            conda-forge/osx-arm64::geotiff-1.7.1-hc898e3f_3
#   gettext            conda-forge/osx-arm64::gettext-0.21.1-h0186832_0
#   giflib             conda-forge/osx-arm64::giflib-5.2.1-h1a8c8d9_3
#   hdf4               conda-forge/osx-arm64::hdf4-4.2.15-h1a38d6a_5
#   icu                conda-forge/osx-arm64::icu-70.1-h6b3803e_0
#   jpeg               conda-forge/osx-arm64::jpeg-9e-he4db4b2_2
#   json-c             conda-forge/osx-arm64::json-c-0.16-hc449e50_0
#   kealib             conda-forge/osx-arm64::kealib-1.4.14-hca62043_4
#   libdap4            conda-forge/osx-arm64::libdap4-3.20.6-h8510809_2
#   libexpat           conda-forge/osx-arm64::libexpat-2.6.2-hebf3989_0
#   libgdal            conda-forge/osx-arm64::libgdal-3.5.1-hb972c36_1
#   libglib            conda-forge/osx-arm64::libglib-2.80.0-hfc324ee_1
#   libiconv           conda-forge/osx-arm64::libiconv-1.17-h0d3ecfb_2
#   libkml             conda-forge/osx-arm64::libkml-1.3.0-h4f02115_1016
#   libnetcdf          conda-forge/osx-arm64::libnetcdf-4.8.1-nompi_h96a3436_102
#   libpq              conda-forge/osx-arm64::libpq-14.5-h1a28acd_5
#   librttopo          conda-forge/osx-arm64::librttopo-1.1.0-h275bb25_11
#   libspatialindex    conda-forge/osx-arm64::libspatialindex-1.9.3-hbdafb3b_4
#   libspatialite      conda-forge/osx-arm64::libspatialite-5.0.1-h97b496e_19
#   libxml2            conda-forge/osx-arm64::libxml2-2.10.3-h67585b2_4
#   libzip             conda-forge/osx-arm64::libzip-1.10.1-ha0bc3c6_3
#   lz4-c              conda-forge/osx-arm64::lz4-c-1.9.4-hb7217d7_0
#   mapclassify        conda-forge/noarch::mapclassify-2.6.1-pyhd8ed1ab_0
#   munch              conda-forge/noarch::munch-4.0.0-pyhd8ed1ab_0
#   networkx           conda-forge/noarch::networkx-3.2.1-pyhd8ed1ab_0
#   nspr               conda-forge/osx-arm64::nspr-4.35-hb7217d7_0
#   nss                conda-forge/osx-arm64::nss-3.98-h5ce2875_0
#   pcre               conda-forge/osx-arm64::pcre-8.45-hbdafb3b_0
#   pcre2              conda-forge/osx-arm64::pcre2-10.43-h26f9a81_0
#   pixman             conda-forge/osx-arm64::pixman-0.43.4-hebf3989_0
#   poppler            conda-forge/osx-arm64::poppler-22.04.0-h4f9e0c6_3
#   poppler-data       conda-forge/noarch::poppler-data-0.4.12-hd8ed1ab_0
#   postgresql         conda-forge/osx-arm64::postgresql-14.5-h45c140d_5
#   proj               conda-forge/osx-arm64::proj-9.0.1-h4c79c2b_1
#   pyproj             conda-forge/osx-arm64::pyproj-3.4.0-py39h4b6117f_0
#   rtree              conda-forge/osx-arm64::rtree-1.2.0-py39hb28b0e7_0
#   shapely            conda-forge/osx-arm64::shapely-1.8.5-py39hda9c22c_1
#   snappy             conda-forge/osx-arm64::snappy-1.1.10-h17c5cce_0
#   tiledb             conda-forge/osx-arm64::tiledb-2.9.4-h824fbfd_0
#   tzcode             conda-forge/osx-arm64::tzcode-2024a-h93a5062_0
#   uriparser          conda-forge/osx-arm64::uriparser-0.9.7-h13dd4ca_1
#   xerces-c           conda-forge/osx-arm64::xerces-c-3.2.4-h627aa08_1
#   xyzservices        conda-forge/noarch::xyzservices-2023.10.1-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   cffi                                1.14.6-py39hda8b47f_0 --> 1.16.0-py39he153c15_0
#   libffi                                     3.3-h9f76cd9_2 --> 3.4.2-h3422bc3_5
#
# The following packages will be DOWNGRADED:
#
#   krb5                                    1.21.2-h92f50d5_0 --> 1.20.1-h69eda48_0
#   lcms2                                     2.16-ha0e7c42_0 --> 2.14-h8193b64_0
#   libcurl                                  8.5.0-h2d989ff_0 --> 8.1.2-h912dcd9_0
#   libdeflate                                1.19-hb547adb_0 --> 1.14-h1a8c8d9_0
#   libjpeg-turbo                            3.0.0-hb547adb_1 --> 2.1.4-h1a8c8d9_0
#   libnghttp2                              1.58.0-ha4dd798_1 --> 1.58.0-ha4dd798_0
#   libtiff                                  4.6.0-ha8a6c65_2 --> 4.4.0-heb92581_5
#   libxcb                                    1.15-hf346824_0 --> 1.13-h9b22ae9_1004
#   openjpeg                                 2.5.2-h9f1df11_0 --> 2.5.0-h5d4e404_1
#   openssl                                  3.2.1-h0d3ecfb_1 --> 3.1.5-h0d3ecfb_0
#   pillow                              10.2.0-py39h755f0b7_0 --> 9.2.0-py39h139752e_3
#
#
#
# Downloading and Extracting Packages:
# pillow-9.2.0         | 45.2 MB   |                                       |   0%
# boost-cpp-1.78.0     | 14.5 MB   |                                       |   0%
#
# icu-70.1             | 13.3 MB   |                                       |   0%
#
#
# libgdal-3.5.1        | 8.3 MB    |                                       |   0%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    |                                       |   0%
#
#
#
#
# postgresql-14.5      | 3.9 MB    |                                       |   0%
#
#
#
#
#
# tiledb-2.9.4         | 3.8 MB    |                                       |   0%
#
#
#
#
#
#
# proj-9.0.1           | 2.7 MB    |                                       |   0%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# libpq-14.5           | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.5        | 2.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.5.1           | 1.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# nss-3.98             | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.04.0      | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 1.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.11.0          | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-4.1.0        | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.20.1          | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.15          | 926 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# pillow-9.2.0         | 45.2 MB   |                                       |   0%
# pillow-9.2.0         | 45.2 MB   | 1                                     |   0%
# pillow-9.2.0         | 45.2 MB   | 2                                     |   1%
# boost-cpp-1.78.0     | 14.5 MB   | ########6                             |  23%
#
# pillow-9.2.0         | 45.2 MB   | 4                                     |   1%
# boost-cpp-1.78.0     | 14.5 MB   | ###########                           |  30%
#
# icu-70.1             | 13.3 MB   | 2                                     |   1%
# pillow-9.2.0         | 45.2 MB   | 6                                     |   2%
#
# icu-70.1             | 13.3 MB   | 5                                     |   2%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | 1                                     |   0%
# pillow-9.2.0         | 45.2 MB   | 8                                     |   2%
# boost-cpp-1.78.0     | 14.5 MB   | ##################3                   |  50%
#
# icu-70.1             | 13.3 MB   | 7                                     |   2%
#
#
#
# pillow-9.2.0         | 45.2 MB   | 9                                     |   3%
# boost-cpp-1.78.0     | 14.5 MB   | ####################5                 |  56%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | #1                                    |   3%
#
# pillow-9.2.0         | 45.2 MB   | #                                     |   3%
# boost-cpp-1.78.0     | 14.5 MB   | ######################9               |  62%
#
# pillow-9.2.0         | 45.2 MB   | #2                                    |   3%
# pillow-9.2.0         | 45.2 MB   | #3                                    |   4%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | #6                                    |   4%
# pillow-9.2.0         | 45.2 MB   | #5                                    |   4%
# boost-cpp-1.78.0     | 14.5 MB   | ##############################2       |  82%
#
# icu-70.1             | 13.3 MB   | #6                                    |   4%
#
#
#
# pillow-9.2.0         | 45.2 MB   | #7                                    |   5%
# boost-cpp-1.78.0     | 14.5 MB   | ################################7     |  88%
#
# pillow-9.2.0         | 45.2 MB   | #8                                    |   5%
# boost-cpp-1.78.0     | 14.5 MB   | ###################################1  |  95%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ##5                                   |   7%
#
# pillow-9.2.0         | 45.2 MB   | ##                                    |   5%
#
# icu-70.1             | 13.3 MB   | ##3                                   |   6%
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##2                                   |   6%
#
#
#
#
# postgresql-14.5      | 3.9 MB    | 1                                     |   0%
#
# icu-70.1             | 13.3 MB   | ##6                                   |   7%
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##4                                   |   7%
#
#
#
#
# postgresql-14.5      | 3.9 MB    | ####6                                 |  12%
#
# pillow-9.2.0         | 45.2 MB   | ##6                                   |   7%
#
#
#
#
# postgresql-14.5      | 3.9 MB    | #############8                        |  37%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ####1                                 |  11%
#
# pillow-9.2.0         | 45.2 MB   | ##8                                   |   8%
#
#
#
#
# postgresql-14.5      | 3.9 MB    | ######################3               |  60%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ####6                                 |  12%
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###1                                  |   8%
#
# icu-70.1             | 13.3 MB   | ###3                                  |   9%
#
#
# libgdal-3.5.1        | 8.3 MB    |                                       |   0%
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###3                                  |   9%
#
# icu-70.1             | 13.3 MB   | ###7                                  |  10%
#
#
# libgdal-3.5.1        | 8.3 MB    | 6                                     |   2%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | #####4                                |  15%
#
#
#
#
# postgresql-14.5      | 3.9 MB    | ##################################### | 100%
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###5                                  |   9%
#
# icu-70.1             | 13.3 MB   | ####                                  |  11%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | #####9                                |  16%
#
#
# pillow-9.2.0         | 45.2 MB   | ###6                                  |  10%
#
# icu-70.1             | 13.3 MB   | ####4                                 |  12%
#
#
# libgdal-3.5.1        | 8.3 MB    | ###4                                  |   9%
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###8                                  |  10%
#
# icu-70.1             | 13.3 MB   | ####7                                 |  13%
#
#
# libgdal-3.5.1        | 8.3 MB    | #####4                                |  15%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ######9                               |  19%
#
# pillow-9.2.0         | 45.2 MB   | ####                                  |  11%
#
#
#
#
#
# tiledb-2.9.4         | 3.8 MB    | 1                                     |   0%
#
#
# libgdal-3.5.1        | 8.3 MB    | #######9                              |  21%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | #######4                              |  20%
#
#
#
#
#
# tiledb-2.9.4         | 3.8 MB    | ##7                                   |   7%
#
# pillow-9.2.0         | 45.2 MB   | ####1                                 |  11%
#
#
# libgdal-3.5.1        | 8.3 MB    | #########6                            |  26%
#
#
#
#
#
# tiledb-2.9.4         | 3.8 MB    | ########7                             |  24%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | #######8                              |  21%
#
# icu-70.1             | 13.3 MB   | ######1                               |  17%
#
#
# pillow-9.2.0         | 45.2 MB   | ####3                                 |  12%
#
#
#
#
#
# tiledb-2.9.4         | 3.8 MB    | #################3                    |  47%
#
# icu-70.1             | 13.3 MB   | ######4                               |  18%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ########3                             |  22%
#
#
# pillow-9.2.0         | 45.2 MB   | ####5                                 |  12%
#
#
#
#
#
# tiledb-2.9.4         | 3.8 MB    | #######################5              |  64%
#
# icu-70.1             | 13.3 MB   | ######9                               |  19%
#
#
#
# pillow-9.2.0         | 45.2 MB   | ####6                                 |  13%
#
#
# libgdal-3.5.1        | 8.3 MB    | ##############4                       |  39%
#
#
#
#
#
# tiledb-2.9.4         | 3.8 MB    | #############################         |  79%
#
# icu-70.1             | 13.3 MB   | #######2                              |  20%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | #########6                            |  26%
#
#
# libgdal-3.5.1        | 8.3 MB    | ###############8                      |  43%
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ####8                                 |  13%
#
# icu-70.1             | 13.3 MB   | #######6                              |  21%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ##########3                           |  28%
#
#
# pillow-9.2.0         | 45.2 MB   | ####9                                 |  13%
#
# icu-70.1             | 13.3 MB   | ########                              |  22%
#
#
#
#
#
#
# proj-9.0.1           | 2.7 MB    | 2                                     |   1%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ##########9                           |  30%
#
#
# libgdal-3.5.1        | 8.3 MB    | ###################2                  |  52%
#
# pillow-9.2.0         | 45.2 MB   | #####1                                |  14%
#
#
#
#
#
#
# proj-9.0.1           | 2.7 MB    | #######4                              |  20%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ###########5                          |  31%
#
#
# pillow-9.2.0         | 45.2 MB   | #####2                                |  14%
#
# icu-70.1             | 13.3 MB   | ########7                             |  24%
#
#
#
#
#
#
# proj-9.0.1           | 2.7 MB    | ###############4                      |  42%
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | #####3                                |  15%
#
#
# libgdal-3.5.1        | 8.3 MB    | ######################                |  60%
#
# icu-70.1             | 13.3 MB   | #########                             |  25%
#
#
#
#
#
#
# proj-9.0.1           | 2.7 MB    | ########################1             |  65%
#
#
#
# pillow-9.2.0         | 45.2 MB   | #####5                                |  15%
#
# icu-70.1             | 13.3 MB   | #########3                            |  25%
#
#
# libgdal-3.5.1        | 8.3 MB    | #######################4              |  63%
#
#
#
#
#
#
# proj-9.0.1           | 2.7 MB    | ###############################1      |  84%
#
#
#
# pillow-9.2.0         | 45.2 MB   | #####7                                |  15%
#
#
# libgdal-3.5.1        | 8.3 MB    | #########################1            |  68%
#
# icu-70.1             | 13.3 MB   | #########8                            |  27%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | 2                                     |   1%
#
#
#
# pillow-9.2.0         | 45.2 MB   | #####8                                |  16%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | #######7                              |  21%
#
# icu-70.1             | 13.3 MB   | ##########2                           |  28%
#
#
# libgdal-3.5.1        | 8.3 MB    | ##########################4           |  72%
#
#
#
# pillow-9.2.0         | 45.2 MB   | #####9                                |  16%
#
# icu-70.1             | 13.3 MB   | ##########5                           |  29%
#
#
# libgdal-3.5.1        | 8.3 MB    | ###########################8          |  75%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | #################                     |  46%
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ######1                               |  17%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ##############2                       |  39%
#
# icu-70.1             | 13.3 MB   | ##########9                           |  30%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##########################5           |  72%
#
#
# pillow-9.2.0         | 45.2 MB   | ######3                               |  17%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ##############8                       |  40%
#
# icu-70.1             | 13.3 MB   | ###########4                          |  31%
#
#
# pillow-9.2.0         | 45.2 MB   | ######5                               |  18%
#
# icu-70.1             | 13.3 MB   | ###########9                          |  32%
#
#
#
#
#
#
#
#
# libpq-14.5           | 2.2 MB    | 2                                     |   1%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ###############4                      |  42%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##################################### | 100%
#
#
# pillow-9.2.0         | 45.2 MB   | ######7                               |  18%
#
# icu-70.1             | 13.3 MB   | ############3                         |  33%
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ######8                               |  19%
#
#
# libgdal-3.5.1        | 8.3 MB    | #################################7    |  91%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ###############8                      |  43%
#
# icu-70.1             | 13.3 MB   | #############                         |  35%
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | #######                               |  19%
#
#
# libgdal-3.5.1        | 8.3 MB    | ###################################5  |  96%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ################3                     |  44%
#
# pillow-9.2.0         | 45.2 MB   | #######2                              |  20%
#
#
#
#
#
#
#
#
# libpq-14.5           | 2.2 MB    | ###########################2          |  74%
# boost-cpp-1.78.0     | 14.5 MB   | ##################################### | 100%
#
#
# libgdal-3.5.1        | 8.3 MB    | ####################################8 | 100%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ################9                     |  46%
#
# pillow-9.2.0         | 45.2 MB   | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.5        | 2.1 MB    | 2                                     |   1%
#
#
#
# pillow-9.2.0         | 45.2 MB   | #######6                              |  21%
#
# icu-70.1             | 13.3 MB   | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.5        | 2.1 MB    | ##########1                           |  27%
#
#
#
#
#
#
#
#
# libpq-14.5           | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libpq-14.5           | 2.2 MB    | ##################################### | 100%
#
#
#
# pillow-9.2.0         | 45.2 MB   | #######8                              |  21%
#
# icu-70.1             | 13.3 MB   | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.5        | 2.1 MB    | ####################5                 |  56%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | 2                                     |   1%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ###################7                  |  53%
#
# icu-70.1             | 13.3 MB   | ###############5                      |  42%
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | #######9                              |  22%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | ####3                                 |  12%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ####################4                 |  55%
#
# pillow-9.2.0         | 45.2 MB   | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.5        | 2.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.5        | 2.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | #########7                            |  26%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ######################2               |  60%
#
# pillow-9.2.0         | 45.2 MB   | ########4                             |  23%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | ##############3                       |  39%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ########################              |  65%
#
#
# libgdal-3.5.1        | 8.3 MB    | ##################################### | 100%
#
# pillow-9.2.0         | 45.2 MB   | ########6                             |  23%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | ##################9                   |  51%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ##########################1           |  71%
#
# pillow-9.2.0         | 45.2 MB   | ########8                             |  24%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | #######################5              |  64%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ############################3         |  77%
#
# pillow-9.2.0         | 45.2 MB   | #########                             |  25%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | ###########################9          |  75%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ##############################1       |  81%
#
# pillow-9.2.0         | 45.2 MB   | #########3                            |  25%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | ################################5     |  88%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | #################################1    |  90%
#
# icu-70.1             | 13.3 MB   | ###################1                  |  52%
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | #########6                            |  26%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | ##################################### | 100%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ###################################9  |  97%
#
# icu-70.1             | 13.3 MB   | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##########                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.5.1           | 1.8 MB    | #8                                    |   5%
#
# icu-70.1             | 13.3 MB   | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##########2                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.5.1           | 1.8 MB    | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
# libdap4-3.20.6       | 2.1 MB    | ##################################### | 100%
#
# icu-70.1             | 13.3 MB   | #####################2                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.5.1           | 1.8 MB    | ########2                             |  22%
#
#
#
# libspatialite-5.0.1  | 3.9 MB    | ##################################### | 100%
#
# icu-70.1             | 13.3 MB   | ######################                |  60%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.5.1           | 1.8 MB    | ################1                     |  44%
#
# icu-70.1             | 13.3 MB   | ######################8               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
# nss-3.98             | 1.7 MB    | ######################4               |  61%
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###########2                          |  30%
#
# icu-70.1             | 13.3 MB   | #######################5              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
# nss-3.98             | 1.7 MB    | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.5.1           | 1.8 MB    | #########################9            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###########4                          |  31%
#
# icu-70.1             | 13.3 MB   | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
# nss-3.98             | 1.7 MB    | #################################4    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.04.0      | 1.6 MB    | #####3                                |  14%
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###########7                          |  32%
#
# icu-70.1             | 13.3 MB   | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ############                          |  33%
#
# icu-70.1             | 13.3 MB   | #########################8            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
# nss-3.98             | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.3 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 1.4 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.04.0      | 1.6 MB    | ##################5                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.3 MB    | #####6                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ############3                         |  33%
#
# icu-70.1             | 13.3 MB   | ##########################5           |  72%
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.5.1           | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# gdal-3.5.1           | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.04.0      | 1.6 MB    | #######################1              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ############5                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 1.4 MB    | ###########8                          |  32%
#
# icu-70.1             | 13.3 MB   | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.04.0      | 1.6 MB    | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 1.4 MB    | ####################3                 |  55%
#
# pillow-9.2.0         | 45.2 MB   | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.04.0      | 1.6 MB    | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.3 MB    | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 1.4 MB    | #########################8            |  70%
#
# pillow-9.2.0         | 45.2 MB   | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.3 MB    | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 1.4 MB    | ################################6     |  88%
#
# pillow-9.2.0         | 45.2 MB   | #############7                        |  37%
#
# pillow-9.2.0         | 45.2 MB   | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.3 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.11.0          | 1.3 MB    | 4                                     |   1%
#
# pillow-9.2.0         | 45.2 MB   | ##############4                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.3 MB    | ####5                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.11.0          | 1.3 MB    | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-4.1.0        | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 1.4 MB    | ##################################### | 100%
#
# icu-70.1             | 13.3 MB   | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.04.0      | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-4.1.0        | 1.2 MB    | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.11.0          | 1.3 MB    | #############8                        |  37%
#
# pillow-9.2.0         | 45.2 MB   | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.3 MB    | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-4.1.0        | 1.2 MB    | ###########1                          |  30%
#
# icu-70.1             | 13.3 MB   | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.3 MB    | ######################6               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-4.1.0        | 1.2 MB    | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.11.0          | 1.3 MB    | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###############7                      |  43%
#
# icu-70.1             | 13.3 MB   | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-4.1.0        | 1.2 MB    | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.11.0          | 1.3 MB    | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ################                      |  43%
#
# icu-70.1             | 13.3 MB   | ##################################9   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-4.1.0        | 1.2 MB    | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.20.1          | 1.0 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ################3                     |  44%
#
# icu-70.1             | 13.3 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-4.1.0        | 1.2 MB    | ####################################4 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.20.1          | 1.0 MB    | #########4                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ########9                             |  24%
#
# pillow-9.2.0         | 45.2 MB   | ################6                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.15          | 926 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cfitsio-4.1.0        | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.11.0          | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.20.1          | 1.0 MB    | ##################2                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ################6                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ################9                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.20.1          | 1.0 MB    | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | #################1                    |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.15          | 926 KB    | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.20.1          | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# krb5-1.20.1          | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | #################6                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.15          | 926 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##################4                   |  50% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##################7                   |  51% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ###################                   |  51% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pillow-9.2.0         | 45.2 MB   | ###################4                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-9.2.0         | 45.2 MB   | ##################################### | 100% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
country_sales = df.groupby('Country')['Total_amount_paid'].sum().reset_index()
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world = world.merge(country_sales, how='left', left_on='name', right_on='Country')

fig, ax = plt.subplots(1, 1, figsize=(15,10))
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.1)
world.plot(column='Total_amount_paid', ax=ax, legend=True, cax=cax, legend_kwds={'label':'Total Amount Paid by Country'})
ax.set_title('Distribution of Sales Across Different Countries')
plt.show()
# Out:
# /var/folders/hq/74v3821x34s_q34x5bq8cnh00000gn/T/ipykernel_43855/3715501965.py:2: FutureWarning:
#
# The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
