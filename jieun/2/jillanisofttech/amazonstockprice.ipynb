# %% [markdown]
# ## 아마존 주식 가격
# 아마존 주가 (2000년부터 Onword)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
df = pd.read_csv('/home/leejieun/workspace/kaggle-notebooks/datasets/jillanisofttech/amazonstockprice/AMZN_Stock_Updated_V2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date      Open      High       Low     Close     Volume
# 0           0  2000-01-03  4.075000  4.478125  3.952344  4.468750  322352000
# 1           1  2000-01-04  4.268750  4.575000  4.087500  4.096875  349748000
# 2           2  2000-01-05  3.525000  3.756250  3.400000  3.487500  769148000
# 3           3  2000-01-06  3.565625  3.634375  3.200000  3.278125  375040000
# 4           4  2000-01-07  3.350000  3.525000  3.309375  3.478125  210108000

# %%
df.tail()
# Out:
#       Unnamed: 0        Date        Open        High         Low       Close  \
# 6045        6045  2024-01-12  155.389999  156.199997  154.009995  154.619995
# 6046        6046  2024-01-16  153.529999  154.990005  152.149994  153.160004
# 6047        6047  2024-01-17  151.490005  152.149994  149.910004  151.710007
# 6048        6048  2024-01-18  152.770004  153.779999  151.820007  153.500000
# 6049        6049  2024-01-19  153.830002  155.759995  152.740005  155.339996
#
#         Volume
# 6045  40460300
# 6046  41384600
# 6047  34953400
# 6048  37850200
# 6049  51033700

# %%
df['Unnamed: 0']
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 6045    6045
# 6046    6046
# 6047    6047
# 6048    6048
# 6049    6049
# Name: Unnamed: 0, Length: 6050, dtype: int64

# %%
df.drop(columns=['Unnamed: 0'], axis=1, inplace=True)

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2000-01-03  4.075000  4.478125  3.952344  4.468750  322352000
# 2000-01-04  4.268750  4.575000  4.087500  4.096875  349748000
# 2000-01-05  3.525000  3.756250  3.400000  3.487500  769148000
# 2000-01-06  3.565625  3.634375  3.200000  3.278125  375040000
# 2000-01-07  3.350000  3.525000  3.309375  3.478125  210108000

# %%
df.index= pd.to_datetime(df.index, format='%Y-%m-%d')

# %%
df.head()
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2000-01-03  4.075000  4.478125  3.952344  4.468750  322352000
# 2000-01-04  4.268750  4.575000  4.087500  4.096875  349748000
# 2000-01-05  3.525000  3.756250  3.400000  3.487500  769148000
# 2000-01-06  3.565625  3.634375  3.200000  3.278125  375040000
# 2000-01-07  3.350000  3.525000  3.309375  3.478125  210108000

# %%
df[['Open', 'Close', 'High', 'Low']].plot(figsize=(20,12))
plt.title('Amazon Stock at all time~')
# Out:
# Text(0.5, 1.0, 'Amazon Stock at all time~')

# %%
df[['Volume']].plot(figsize=(20,10), alpha =1)
plt.xlabel('Date')
plt.ylabel('Stock action')
plt.show()
